# %% [markdown]
# <a href="https://colab.research.google.com/github/QuickLearner171998/capsnet-traffic-sign-classifier/blob/master/Traffic_Sign_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive
# %cd 'My Drive'
# %cd 'MY Projects'
# %cd 'EEE lop'
# %cd capsnet-traffic-sign-classifier
# Out:
# /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/MY Projects
# /content/drive/My Drive/MY Projects/EEE lop
# /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier

# %%
# !wget https://d17h27t6h515a5.cloudfront.net/topher/2017/February/5898cd6f_traffic-signs-data/traffic-signs-data.zip

# %%
# !unzip traffic-signs-data.zip
# !mkdir dataset
# !mv *.p dataset/
# !rm traffic-signs-data.zip

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = "dataset/train.p"
validation_file= "dataset/valid.p"
testing_file = "dataset/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# Print the shape of variables
print(X_train.shape)
print(y_train.shape)
# Out:
# (34799, 32, 32, 3)
# (34799,)

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training example
n_train = X_train.shape[0]

# TODO: Number of validation example
n_validation = X_valid.shape[0]

# TODO: Number of testing example.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train.shape[1:]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
import random
from PIL import Image
import numpy as np
import random
from PIL import Image, ImageEnhance
# Visualizations will be shown in the notebook.
# %matplotlib inline

# Load name of id
with open("signnames.csv", "r") as f:
    signnames = f.read()
id_to_name = { int(line.split(",")[0]):line.split(",")[1] for line in signnames.split("\n")[1:] if len(line) > 0}


graph_size = 3
random_index_list = [random.randint(0, X_train.shape[0]) for _ in range(graph_size * graph_size)]
fig = plt.figure(figsize=(15, 15))
for i, index in enumerate(random_index_list):
    a=fig.add_subplot(graph_size, graph_size, i+1)
    #im = Image.fromarray(np.rollaxis(X_train[index] * 255, 0,3))
    imgplot = plt.imshow(X_train[index])
    # Plot some images
    a.set_title('%s' % id_to_name[y_train[index]])

plt.show()



fig, ax = plt.subplots()
# the histogram of the data
values, bins, patches = ax.hist(y_train, n_classes, normed=10)

# add a 'best fit' line
ax.set_xlabel('Smarts')
ax.set_title(r'Histogram of classess')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()

print ("Most common index")
most_common_index = sorted(range(len(values)), key=lambda k: values[k], reverse=True)
for index in most_common_index[:10]:
    print("index: %s => %s = %s" % (index, id_to_name[index], values[index]))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# Most common index
# index: 2 => Speed limit (50km/h) = 0.0591355252408731
# index: 1 => Speed limit (30km/h) = 0.05825290546115858
# index: 13 => Yield = 0.056487665901729524
# index: 12 => Priority road = 0.055605046122015
# index: 38 => Keep right = 0.05472242634230058
# index: 10 => No passing for vehicles over 3.5 metric tons = 0.05295718678287143
# index: 4 => Speed limit (70km/h) = 0.05207456700315691
# index: 5 => Speed limit (80km/h) = 0.048544087884298814
# index: 25 => Road work = 0.0397178900871535
# index: 9 => No passing = 0.03883527030743905

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

#  I used keras only for the ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator


X_train = X_train / 255
X_valid = X_valid / 255
X_test = X_test / 255
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def preprocessing_function(img):
    """
        Custom preprocessing_function
    """
    img = img * 255
    img = Image.fromarray(img.astype('uint8'), 'RGB')
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.6, 1.5))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.6, 1.5))

    return np.array(img) / 255

train_datagen = ImageDataGenerator()
train_datagen_augmented = ImageDataGenerator(
    rotation_range=20,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    preprocessing_function=preprocessing_function)
inference_datagen = ImageDataGenerator()
train_datagen.fit(X_train)
train_datagen_augmented.fit(X_train)
inference_datagen.fit(X_valid)
inference_datagen.fit(X_test)

# %% [markdown]
# ### Exemple of augmented images

# %%
fig = plt.figure()

n = 0

graph_size = 3

for x_batch, y_batch in train_datagen_augmented.flow(X_train, y_train, batch_size=1):
    a=fig.add_subplot(graph_size, graph_size, n+1)
    imgplot = plt.imshow(x_batch[0])
    n = n + 1
    if n > 8:
        break

    
plt.show()

# %% [markdown]
# ## Model Architecture

# %% [markdown]
# ### CapsNet

# %%
import numpy as np
import tensorflow as tf
import numpy as np


def conv_caps_layer(input_layer, capsules_size, nb_filters, kernel, stride=2):
    """
        Capsule layer for the convolutional inputs
        **input:
            *input_layer: (Tensor)
            *capsule_numbers: (Integer) the number of capsule in this layer.
            *kernel_size: (Integer) Size of the kernel for each filter.
            *stride: (Integer) 2 by default
    """
    # "In convolutional capsule layers each unit in a capsule is a convolutional unit.
    # Therefore, each capsule will output a grid of vectors rather than a single vector output."
    capsules = tf.contrib.layers.conv2d(
        input_layer, nb_filters * capsules_size, kernel, stride, padding="VALID")
    # conv shape: [?, kernel, kernel, nb_filters]
    shape = capsules.get_shape().as_list()
    capsules = tf.reshape(capsules, shape=(-1, np.prod(shape[1:3]) * nb_filters, capsules_size, 1))
    # capsules shape: [?, nb_capsules, capsule_size, 1]
    return squash(capsules)

def routing(u_hat, b_ij, nb_capsules, nb_capsules_p, iterations=4):
    """
        Routing algorithm

        **input:
            *u_hat: Dot product (weights between previous capsule and current capsule)
            *b_ij: the log prior probabilities that capsule i should be coupled to capsule j
            *nb_capsules_p: Number of capsule in the previous layer
            *nb_capsules: Number of capsule in this layer
    """
    # Start the routing algorithm
    for it in range(iterations):
        with tf.variable_scope('routing_' + str(it)):
            # Line 4 of algo
            # probabilities that capsule i should be coupled to capsule j.
            # c_ij:  [nb_capsules_p, nb_capsules, 1, 1]
            c_ij = tf.nn.softmax(b_ij, dim=2)

            # Line 5 of algo
            # c_ij:  [      nb_capsules_p, nb_capsules, 1,         1]
            # u_hat: [?,    nb_capsules_p, nb_capsules, len_v_j,   1]
            s_j = tf.multiply(c_ij, u_hat)
            # s_j: [?, nb_capsules_p, nb_capsules, len_v_j, 1]
            s_j = tf.reduce_sum(s_j, axis=1, keep_dims=True)
            # s_j: [?, 1, nb_capsules, len_v_j, 1)

            # line 6:
            # squash using Eq.1,
            v_j = squash(s_j)
            # v_j: [1, 1, nb_capsules, len_v_j, 1)

            # line 7:
            # Frist reshape & tile v_j
            # [? ,  1,              nb_capsules,    len_v_j, 1] ->
            # [?,   nb_capsules_p,  nb_capsules,    len_v_j, 1]
            v_j_tiled = tf.tile(v_j, [1, nb_capsules_p, 1, 1, 1])
            # u_hat:    [?,             nb_capsules_p, nb_capsules, len_v_j, 1]
            # v_j_tiled [1,             nb_capsules_p, nb_capsules, len_v_j, 1]
            u_dot_v = tf.matmul(u_hat, v_j_tiled, transpose_a=True)
            # u_produce_v: [?, nb_capsules_p, nb_capsules, 1, 1]
            b_ij += tf.reduce_sum(u_dot_v, axis=0, keep_dims=True)
            #b_ih: [1, nb_capsules_p, nb_capsules, 1, 1]

    return tf.squeeze(v_j, axis=1)

def fully_connected_caps_layer(input_layer, capsules_size, nb_capsules, iterations=4):
    """
        Second layer receiving inputs from all capsules of the layer below
            **input:
                *input_layer: (Tensor)
                *capsules_size: (Integer) Size of each capsule
                *nb_capsules: (Integer) Number of capsule
                *iterations: (Integer) Number of iteration for the routing algorithm

            i refer to the layer below.
            j refer to the layer above (the current layer).
    """
    shape = input_layer.get_shape().as_list()
    # Get the size of each capsule in the previous layer and the current layer.
    len_u_i = np.prod(shape[2])
    len_v_j = capsules_size
    # Get the number of capsule in the layer bellow.
    nb_capsules_p = np.prod(shape[1])

    # w_ij: Used to compute u_hat by multiplying the output ui of a capsule in the layer below
    # with this matrix
    # [nb_capsules_p, nb_capsules, len_v_j, len_u_i]
    _init = tf.random_normal_initializer(stddev=0.01, seed=0)
    _shape = (nb_capsules_p, nb_capsules, len_v_j, len_u_i)
    w_ij = tf.get_variable('weight', shape=_shape, dtype=tf.float32, initializer=_init)

    # Adding one dimension to the input [batch_size, nb_capsules_p,    length(u_i), 1] ->
    #                                   [batch_size, nb_capsules_p, 1, length(u_i), 1]
    # To allow the next dot product
    input_layer = tf.reshape(input_layer, shape=(-1, nb_capsules_p, 1, len_u_i, 1))
    input_layer = tf.tile(input_layer, [1, 1, nb_capsules, 1, 1])

    # Eq.2, calc u_hat
    # Prediction uj|i made by capsule i
    # w_ij:  [              nb_capsules_p, nb_capsules, len_v_j,  len_u_i, ]
    # input: [batch_size,   nb_capsules_p, nb_capsules, len_ui,   1]
    # u_hat: [batch_size,   nb_capsules_p, nb_capsules, len_v_j, 1]
    # Each capsule of the previous layer capsule layer is associated to a capsule of this layer
    u_hat = tf.einsum('abdc,iabcf->iabdf', w_ij, input_layer)

    # bij are the log prior probabilities that capsule i should be coupled to capsule j
    # [nb_capsules_p, nb_capsules, 1, 1]
    b_ij = tf.zeros(shape=[nb_capsules_p, nb_capsules, 1, 1], dtype=np.float32)

    return routing(u_hat, b_ij, nb_capsules, nb_capsules_p, iterations=iterations)

def squash(vector):
    """
        Squashing function corresponding to Eq. 1
        **input: **
            *vector
    """
    vector += 0.00001 # Workaround for the squashing function ...
    vec_squared_norm = tf.reduce_sum(tf.square(vector), -2, keep_dims=True)
    scalar_factor = vec_squared_norm / (1 + vec_squared_norm) / tf.sqrt(vec_squared_norm)
    vec_squashed = scalar_factor * vector  # element-wise
    return(vec_squashed)

# %% [markdown]
# ### Main Model

# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-

import numpy as np
from model_base import ModelBase
import tensorflow as tf

class ModelTrafficSign(ModelBase):
    """
        ModelTrafficSign.
        This class is used to create the conv graph using:
            Dynamic Routing Between Capsules
    """

    # Numbers of label to predict
    NB_LABELS = 43

    def __init__(self, model_name, output_folder):
        """
            **input:
                *model_name: (Integer) Name of this model
                *output_folder: Output folder to saved data (tensorboard, checkpoints)
        """
        ModelBase.__init__(self, model_name, output_folder=output_folder)

    def _build_inputs(self):
        """
            Build tensorflow inputs
            (Placeholder)
            **return: **
                *tf_images: Images Placeholder
                *tf_labels: Labels Placeholder
        """
        # Images 32*32*3
        tf_images = tf.placeholder(tf.float32, [None, 32, 32, 3], name='images')
        # Labels: [0, 1, 6, 20, ...]
        tf_labels = tf.placeholder(tf.int64, [None], name='labels')
        return tf_images, tf_labels

    def _build_main_network(self, images, conv_2_dropout):
        """
            This method is used to create the two convolutions and the CapsNet on the top
            **input:
                *images: Image PLaceholder
                *conv_2_dropout: Dropout value placeholder
            **return: **
                *Caps1: Output of first Capsule layer
                *Caps2: Output of second Capsule layer
        """
        # First BLock:
        # Layer 1: Convolution.
        shape = (self.h.conv_1_size, self.h.conv_1_size, 3, self.h.conv_1_nb)
        conv1 = self._create_conv(self.tf_images, shape, relu=True, max_pooling=False, padding='VALID')
        # Layer 2: Convolution.
        #shape = (self.h.conv_2_size, self.h.conv_2_size, self.h.conv_1_nb, self.h.conv_2_nb)
        #conv2 = self._create_conv(conv1, shape, relu=True, max_pooling=False, padding='VALID')
        conv1 = tf.nn.dropout(conv1, keep_prob=conv_2_dropout)

        # Create the first capsules layer
        caps1 = conv_caps_layer(
            input_layer=conv1,
            capsules_size=self.h.caps_1_vec_len,
            nb_filters=self.h.caps_1_nb_filter,
            kernel=self.h.caps_1_size)
        # Create the second capsules layer used to predict the output
        caps2 = fully_connected_caps_layer(
            input_layer=caps1,
            capsules_size=self.h.caps_2_vec_len,
            nb_capsules=self.NB_LABELS,
            iterations=self.h.routing_steps)

        return caps1, caps2

    def _build_decoder(self, caps2, one_hot_labels, batch_size):
        """
            Build the decoder part from the last capsule layer
            **input:
                *Caps2:  Output of second Capsule layer
                *one_hot_labels
                *batch_size
        """
        labels = tf.reshape(one_hot_labels, (-1, self.NB_LABELS, 1))
        # squeeze(caps2):   [?, len_v_j,    capsules_nb]
        # labels:           [?, NB_LABELS,  1] with capsules_nb == NB_LABELS
        mask = tf.matmul(tf.squeeze(caps2), labels, transpose_a=True)
        # Select the good capsule vector
        capsule_vector = tf.reshape(mask, shape=(batch_size, self.h.caps_2_vec_len))
        # capsule_vector: [?, len_v_j]

        # Reconstruct image
        fc1 = tf.contrib.layers.fully_connected(capsule_vector, num_outputs=400)
        fc1 = tf.reshape(fc1, shape=(batch_size, 5, 5, 16))
        upsample1 = tf.image.resize_nearest_neighbor(fc1, (8, 8))
        conv1 = tf.layers.conv2d(upsample1, 4, (3,3), padding='same', activation=tf.nn.relu)

        upsample2 = tf.image.resize_nearest_neighbor(conv1, (16, 16))
        conv2 = tf.layers.conv2d(upsample2, 8, (3,3), padding='same', activation=tf.nn.relu)

        upsample3 = tf.image.resize_nearest_neighbor(conv2, (32, 32))
        conv6 = tf.layers.conv2d(upsample3, 16, (3,3), padding='same', activation=tf.nn.relu)

        # 3 channel for RGG
        logits = tf.layers.conv2d(conv6, 3, (3,3), padding='same', activation=None)
        decoded = tf.nn.sigmoid(logits, name='decoded')
        tf.summary.image('reconstruction_img', decoded)

        return decoded

    def init(self):
        """
            Init the graph
        """
        # Get graph inputs
        self.tf_images, self.tf_labels = self._build_inputs()
        # Dropout inputs
        self.tf_conv_2_dropout = tf.placeholder(tf.float32, shape=(), name='conv_2_dropout')
        # Dynamic batch size
        batch_size = tf.shape(self.tf_images)[0]
        # Translate labels to one hot array
        one_hot_labels = tf.one_hot(self.tf_labels, depth=self.NB_LABELS)
        # Create the first convolution and the CapsNet
        self.tf_caps1, self.tf_caps2 = self._build_main_network(self.tf_images, self.tf_conv_2_dropout)

        # Build the images reconstruction
        self.tf_decoded = self._build_decoder(self.tf_caps2, one_hot_labels, batch_size)

        # Build the loss
        _loss = self._build_loss(
            self.tf_caps2, one_hot_labels, self.tf_labels, self.tf_decoded, self.tf_images)
        (self.tf_loss_squared_rec, self.tf_margin_loss_sum, self.tf_predicted_class,
         self.tf_correct_prediction, self.tf_accuracy, self.tf_loss, self.tf_margin_loss,
         self.tf_reconstruction_loss) = _loss

        # Build optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate=self.h.learning_rate)
        self.tf_optimizer = optimizer.minimize(self.tf_loss, global_step=tf.Variable(0, trainable=False))

        # Log value into tensorboard
        tf.summary.scalar('margin_loss', self.tf_margin_loss)
        tf.summary.scalar('accuracy', self.tf_accuracy)
        tf.summary.scalar('total_loss', self.tf_loss)
        tf.summary.scalar('reconstruction_loss', self.tf_reconstruction_loss)

        self.tf_test = tf.random_uniform([2], minval=0, maxval=None, dtype=tf.float32, seed=None, name="tf_test")

        self.init_session()


    def _build_loss(self, caps2, one_hot_labels, labels, decoded, images):
        """
            Build the loss of the graph
        """
        # Get the length of each capsule
        capsules_length = tf.sqrt(tf.reduce_sum(tf.square(caps2), axis=2, keep_dims=True))

        max_l = tf.square(tf.maximum(0., 0.9 - capsules_length))
        max_l = tf.reshape(max_l, shape=(-1, self.NB_LABELS))
        max_r = tf.square(tf.maximum(0., capsules_length - 0.1))
        max_r = tf.reshape(max_r, shape=(-1, self.NB_LABELS))
        t_c = one_hot_labels
        m_loss = t_c * max_l + 0.5 * (1 - t_c) * max_r
        margin_loss_sum = tf.reduce_sum(m_loss, axis=1)
        margin_loss = tf.reduce_mean(margin_loss_sum)

        # Reconstruction loss
        loss_squared_rec = tf.square(decoded - images)
        reconstruction_loss = tf.reduce_mean(loss_squared_rec)

        # 3. Total loss
        loss = margin_loss + (0.0005 * reconstruction_loss)

        # Accuracy
        predicted_class = tf.argmax(capsules_length, axis=1)
        predicted_class = tf.reshape(predicted_class, [tf.shape(capsules_length)[0]])
        correct_prediction = tf.equal(predicted_class, labels)
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

        return (loss_squared_rec, margin_loss_sum, predicted_class, correct_prediction, accuracy,
                loss, margin_loss, reconstruction_loss)

    def optimize(self, images, labels, tb_save=True):
        """
            Train the model
            **input: **
                *images: Image to train the model on
                *labels: True classes
                *tb_save: (Boolean) Log this optimization in tensorboard
            **return: **
                Loss: The loss of the model on this batch
                Acc: Accuracy of the model on this batch
        """
        tensors = [self.tf_optimizer, self.tf_margin_loss, self.tf_accuracy, self.tf_tensorboard]
        _, loss, acc, summary = self.sess.run(tensors,
            feed_dict={
            self.tf_images: images,
            self.tf_labels: labels,
            self.tf_conv_2_dropout: self.h.conv_2_dropout
        })

        if tb_save:
            # Write data to tensorboard
            self.train_writer.add_summary(summary, self.train_writer_it)
            self.train_writer_it += 1

        return loss, acc

    def evaluate(self, images, labels, tb_train_save=False, tb_test_save=False):
        """
            Evaluate dataset
            **input: **
                *images: Image to train the model on
                *labels: True classes
                *tb_train_save: (Boolean) Log this optimization in tensorboard under the train part
                *tb_test_save: (Boolean) Log this optimization in tensorboard under the test part
            **return: **
                Loss: The loss of the model on this batch
                Acc: Accuracy of the model on this batch
        """
        tensors = [self.tf_margin_loss, self.tf_accuracy, self.tf_tensorboard]
        loss, acc, summary = self.sess.run(tensors,
                feed_dict={
                self.tf_images: images,
                self.tf_labels: labels,
                self.tf_conv_2_dropout: 1.
            })

        if tb_test_save:
            # Write data to tensorboard
            self.test_writer.add_summary(summary, self.test_writer_it)
            self.test_writer_it += 1

        if tb_train_save:
            # Write data to tensorboard
            self.train_writer.add_summary(summary, self.train_writer_it)
            self.train_writer_it += 1

        return loss, acc

    def predict(self, images):
        """
            Method used to predict a class
            Return a softmax
            **input: **
                *images: Image to train the model on
            **return:
                *softmax: Softmax between all capsules
        """
        tensors = [self.tf_caps2]

        caps2 = self.sess.run(tensors,
            feed_dict={
            self.tf_images: images,
            self.tf_conv_2_dropout: 1.
        })[0]

        # tf.sqrt(tf.reduce_sum(tf.square(caps2), axis=2, keep_dims=True))
        caps2 = np.sqrt(np.sum(np.square(caps2), axis=2, keepdims=True))
        caps2 = np.reshape(caps2, (len(images), self.NB_LABELS))
        # softmax
        softmax = np.exp(caps2) / np.sum(np.exp(caps2), axis=1, keepdims=True)

        return softmax

    def reconstruction(self, images, labels):
        """
            Method used to get the reconstructions given a batch
            Return the result as a softmax
            **input: **
                *images: Image to train the model on
                *labels: True classes
        """
        tensors = [self.tf_decoded]

        decoded = self.sess.run(tensors,
            feed_dict={
            self.tf_images: images,
            self.tf_labels: labels,
            self.tf_conv_2_dropout: 1.
        })[0]

        return decoded

    def evaluate_dataset(self, images, labels, batch_size=10):
        """
            Evaluate a full dataset
            This method is used to fully evaluate the dataset batch per batch. Useful when
            the dataset can't be fit inside to the GPU.
            *input: **
                *images: Image to train the model on
                *labels: True classes
            *return: **
                *loss: Loss overall your dataset
                *accuracy: Accuracy overall your dataset
                *predicted_class: Predicted class
        """
        tensors = [self.tf_loss_squared_rec, self.tf_margin_loss_sum, self.tf_correct_prediction,
                   self.tf_predicted_class]

        loss_squared_rec_list = None
        margin_loss_sum_list = None
        correct_prediction_list = None
        predicted_class = None

        b = 0
        for batch in self.get_batches([images, labels], batch_size, shuffle=False):
            images_batch, labels_batch = batch
            loss_squared_rec, margin_loss_sum, correct_prediction, classes = self.sess.run(tensors,
                feed_dict={
                self.tf_images: images_batch,
                self.tf_labels: labels_batch,
                self.tf_conv_2_dropout: 1.
            })
            if loss_squared_rec_list is not None:
                predicted_class = np.concatenate((predicted_class, classes))
                loss_squared_rec_list = np.concatenate((loss_squared_rec_list, loss_squared_rec))
                margin_loss_sum_list = np.concatenate((margin_loss_sum_list, margin_loss_sum))
                correct_prediction_list = np.concatenate((correct_prediction_list, correct_prediction))
            else:
                predicted_class = classes
                loss_squared_rec_list = loss_squared_rec
                margin_loss_sum_list = margin_loss_sum
                correct_prediction_list = correct_prediction
            b += batch_size

        margin_loss = np.mean(margin_loss_sum_list)
        reconstruction_loss = np.mean(loss_squared_rec_list)
        accuracy = np.mean(correct_prediction_list)

        loss = margin_loss

        return loss, accuracy, predicted_class

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
# Init model
model = ModelTrafficSign("TrafficSign", output_folder="outputs")
model.init()
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:91: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:91: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
# WARNING:tensorflow:From <ipython-input-10-366eadfc2ea1>:55: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# From <ipython-input-10-366eadfc2ea1>:55: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# NumExpr defaulting to 2 threads.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-9-dd02c8ee4fa1>:123: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# From <ipython-input-9-dd02c8ee4fa1>:123: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-9-dd02c8ee4fa1>:41: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# From <ipython-input-9-dd02c8ee4fa1>:41: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From <ipython-input-10-366eadfc2ea1>:92: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# From <ipython-input-10-366eadfc2ea1>:92: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:134: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:134: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:135: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:135: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:137: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:137: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:139: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:139: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# WARNING:tensorflow:From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:144: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# From /content/drive/My Drive/MY Projects/EEE lop/capsnet-traffic-sign-classifier/model_base.py:144: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

BATCH_SIZE = 50

# Utils method to print the current progression
def plot_progression(b, cost, acc, label): print(
    "[%s] Batch ID = %s, loss = %s, acc = %s" % (label, b, cost, acc))

# Training pipeline
b = 0
valid_batch = inference_datagen.flow(X_valid, y_valid, batch_size=BATCH_SIZE)
best_validation_loss = None
augmented_factor = 0.99
decrease_factor = 0.90
train_batches = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)
augmented_train_batches = train_datagen_augmented.flow(X_train, y_train, batch_size=BATCH_SIZE)
epochs = 10000
for e in range(epochs) :
    next_batch = next(
        augmented_train_batches if random.uniform(0, 1) < augmented_factor else train_batches)
    x_batch, y_batch = next_batch

    ### Training
    cost, acc = model.optimize(x_batch, y_batch)
    ### Validation
    x_batch, y_batch = next(valid_batch, None)
    # Retrieve the cost and acc on this validation batch and save it in tensorboard
    cost_val, acc_val = model.evaluate(x_batch, y_batch, tb_test_save=True)

    if b % 10 == 0: # Plot the last results
        plot_progression(b, cost, acc, "Train")
        plot_progression(b, cost_val, acc_val, "Validation")
    if b % 1000 == 0: # Test the model on all the validation
        print("Evaluate full validation dataset ...")
        loss, acc, _ = model.evaluate_dataset(X_valid, y_valid)
        print("Current loss: %s Best loss: %s" % (loss, best_validation_loss))
        plot_progression(b, loss, acc, "TOTAL Validation")
        if best_validation_loss is None or loss < best_validation_loss:
            best_validation_loss = loss
            model.save()
        augmented_factor = augmented_factor * decrease_factor
        print("Augmented Factor = %s" % augmented_factor)

    b += 1
# Out:
# [Train] Batch ID = 0, loss = 5.661889, acc = 0.02
# [Validation] Batch ID = 0, loss = 2.0533416, acc = 0.02
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 1.7901701 Best loss: None
# [TOTAL Validation] Batch ID = 0, loss = 1.7901701, acc = 0.006802721088435374
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.891
# [Train] Batch ID = 10, loss = 0.77413696, acc = 0.02
# [Validation] Batch ID = 10, loss = 0.79588693, acc = 0.04
# [Train] Batch ID = 20, loss = 0.7067212, acc = 0.14
# [Validation] Batch ID = 20, loss = 0.7310028, acc = 0.02
# [Train] Batch ID = 30, loss = 0.6918066, acc = 0.04
# [Validation] Batch ID = 30, loss = 0.70713806, acc = 0.0
# [Train] Batch ID = 40, loss = 0.66994834, acc = 0.1
# [Validation] Batch ID = 40, loss = 0.6584269, acc = 0.06
# [Train] Batch ID = 50, loss = 0.6694327, acc = 0.02
# [Validation] Batch ID = 50, loss = 0.620519, acc = 0.12
# [Train] Batch ID = 60, loss = 0.62274057, acc = 0.04
# [Validation] Batch ID = 60, loss = 0.6208628, acc = 0.08
# [Train] Batch ID = 70, loss = 0.62001747, acc = 0.1
# [Validation] Batch ID = 70, loss = 0.6167913, acc = 0.04
# [Train] Batch ID = 80, loss = 0.5905389, acc = 0.2
# [Validation] Batch ID = 80, loss = 0.6160675, acc = 0.02
# [Train] Batch ID = 90, loss = 0.6239657, acc = 0.0
# [Validation] Batch ID = 90, loss = 0.62693256, acc = 0.04
# [Train] Batch ID = 100, loss = 0.6242085, acc = 0.1
# [Validation] Batch ID = 100, loss = 0.594904, acc = 0.16
# [Train] Batch ID = 110, loss = 0.5839575, acc = 0.12
# [Validation] Batch ID = 110, loss = 0.6064086, acc = 0.08
# [Train] Batch ID = 120, loss = 0.57696086, acc = 0.08
# [Validation] Batch ID = 120, loss = 0.5984026, acc = 0.16
# [Train] Batch ID = 130, loss = 0.5978458, acc = 0.1
# [Validation] Batch ID = 130, loss = 0.5846364, acc = 0.16
# [Train] Batch ID = 140, loss = 0.58364767, acc = 0.12
# [Validation] Batch ID = 140, loss = 0.56360865, acc = 0.16
# [Train] Batch ID = 150, loss = 0.59663445, acc = 0.06
# [Validation] Batch ID = 150, loss = 0.58814055, acc = 0.14
# [Train] Batch ID = 160, loss = 0.5764605, acc = 0.16
# [Validation] Batch ID = 160, loss = 0.5745692, acc = 0.14
# [Train] Batch ID = 170, loss = 0.585535, acc = 0.1
# [Validation] Batch ID = 170, loss = 0.5938265, acc = 0.1
# [Train] Batch ID = 180, loss = 0.5933852, acc = 0.18
# [Validation] Batch ID = 180, loss = 0.5557594, acc = 0.18
# [Train] Batch ID = 190, loss = 0.5577021, acc = 0.2
# [Validation] Batch ID = 190, loss = 0.58119416, acc = 0.08
# [Train] Batch ID = 200, loss = 0.5834272, acc = 0.04
# [Validation] Batch ID = 200, loss = 0.58460736, acc = 0.08
# [Train] Batch ID = 210, loss = 0.5866748, acc = 0.2
# [Validation] Batch ID = 210, loss = 0.58509564, acc = 0.1
# [Train] Batch ID = 220, loss = 0.57707864, acc = 0.18
# [Validation] Batch ID = 220, loss = 0.55616564, acc = 0.2
# [Train] Batch ID = 230, loss = 0.5794811, acc = 0.1
# [Validation] Batch ID = 230, loss = 0.555367, acc = 0.2
# [Train] Batch ID = 240, loss = 0.5641409, acc = 0.16
# [Validation] Batch ID = 240, loss = 0.58212817, acc = 0.16
# [Train] Batch ID = 250, loss = 0.6140876, acc = 0.06
# [Validation] Batch ID = 250, loss = 0.545142, acc = 0.24
# [Train] Batch ID = 260, loss = 0.5611725, acc = 0.14
# [Validation] Batch ID = 260, loss = 0.5643651, acc = 0.06
# [Train] Batch ID = 270, loss = 0.57784176, acc = 0.14
# [Validation] Batch ID = 270, loss = 0.5424848, acc = 0.2
# [Train] Batch ID = 280, loss = 0.5603715, acc = 0.14
# [Validation] Batch ID = 280, loss = 0.5715827, acc = 0.14
# [Train] Batch ID = 290, loss = 0.54646, acc = 0.3
# [Validation] Batch ID = 290, loss = 0.5226625, acc = 0.3
# [Train] Batch ID = 300, loss = 0.55491483, acc = 0.12
# [Validation] Batch ID = 300, loss = 0.58289576, acc = 0.14
# [Train] Batch ID = 310, loss = 0.56756663, acc = 0.22
# [Validation] Batch ID = 310, loss = 0.5233916, acc = 0.2
# [Train] Batch ID = 320, loss = 0.5745453, acc = 0.1
# [Validation] Batch ID = 320, loss = 0.51048726, acc = 0.3
# [Train] Batch ID = 330, loss = 0.566481, acc = 0.24
# [Validation] Batch ID = 330, loss = 0.5320295, acc = 0.22
# [Train] Batch ID = 340, loss = 0.5523832, acc = 0.18
# [Validation] Batch ID = 340, loss = 0.5802722, acc = 0.16
# [Train] Batch ID = 350, loss = 0.5123071, acc = 0.2
# [Validation] Batch ID = 350, loss = 0.5736137, acc = 0.16
# [Train] Batch ID = 360, loss = 0.5562202, acc = 0.18
# [Validation] Batch ID = 360, loss = 0.5444874, acc = 0.22
# [Train] Batch ID = 370, loss = 0.56257594, acc = 0.2
# [Validation] Batch ID = 370, loss = 0.53791624, acc = 0.2
# [Train] Batch ID = 380, loss = 0.548847, acc = 0.14
# [Validation] Batch ID = 380, loss = 0.52760255, acc = 0.28
# [Train] Batch ID = 390, loss = 0.5753954, acc = 0.14
# [Validation] Batch ID = 390, loss = 0.5407385, acc = 0.2
# [Train] Batch ID = 400, loss = 0.57469344, acc = 0.1
# [Validation] Batch ID = 400, loss = 0.53264886, acc = 0.24
# [Train] Batch ID = 410, loss = 0.53355145, acc = 0.22
# [Validation] Batch ID = 410, loss = 0.5428921, acc = 0.14
# [Train] Batch ID = 420, loss = 0.5515077, acc = 0.2
# [Validation] Batch ID = 420, loss = 0.5369107, acc = 0.2
# [Train] Batch ID = 430, loss = 0.55683327, acc = 0.14
# [Validation] Batch ID = 430, loss = 0.5317776, acc = 0.22
# [Train] Batch ID = 440, loss = 0.5598027, acc = 0.12
# [Validation] Batch ID = 440, loss = 0.5302288, acc = 0.26
# [Train] Batch ID = 450, loss = 0.48678833, acc = 0.3
# [Validation] Batch ID = 450, loss = 0.50879645, acc = 0.28
# [Train] Batch ID = 460, loss = 0.54456806, acc = 0.22
# [Validation] Batch ID = 460, loss = 0.54694974, acc = 0.08
# [Train] Batch ID = 470, loss = 0.56643397, acc = 0.1
# [Validation] Batch ID = 470, loss = 0.47943646, acc = 0.42
# [Train] Batch ID = 480, loss = 0.57820183, acc = 0.16
# [Validation] Batch ID = 480, loss = 0.55804026, acc = 0.2
# [Train] Batch ID = 490, loss = 0.5499786, acc = 0.2
# [Validation] Batch ID = 490, loss = 0.5381073, acc = 0.2
# [Train] Batch ID = 500, loss = 0.53412795, acc = 0.24
# [Validation] Batch ID = 500, loss = 0.49867302, acc = 0.32
# [Train] Batch ID = 510, loss = 0.52384585, acc = 0.28
# [Validation] Batch ID = 510, loss = 0.5176122, acc = 0.22
# [Train] Batch ID = 520, loss = 0.5374551, acc = 0.22
# [Validation] Batch ID = 520, loss = 0.50407594, acc = 0.26
# [Train] Batch ID = 530, loss = 0.54937416, acc = 0.14
# [Validation] Batch ID = 530, loss = 0.5206353, acc = 0.24
# [Train] Batch ID = 540, loss = 0.4967887, acc = 0.24
# [Validation] Batch ID = 540, loss = 0.5157395, acc = 0.28
# [Train] Batch ID = 550, loss = 0.5319444, acc = 0.26
# [Validation] Batch ID = 550, loss = 0.5130477, acc = 0.18
# [Train] Batch ID = 560, loss = 0.53545225, acc = 0.24
# [Validation] Batch ID = 560, loss = 0.4872525, acc = 0.34
# [Train] Batch ID = 570, loss = 0.54641294, acc = 0.26
# [Validation] Batch ID = 570, loss = 0.5036989, acc = 0.3
# [Train] Batch ID = 580, loss = 0.5524399, acc = 0.18
# [Validation] Batch ID = 580, loss = 0.52383536, acc = 0.28
# [Train] Batch ID = 590, loss = 0.5617246, acc = 0.18
# [Validation] Batch ID = 590, loss = 0.47373024, acc = 0.36
# [Train] Batch ID = 600, loss = 0.5570215, acc = 0.12
# [Validation] Batch ID = 600, loss = 0.512339, acc = 0.28
# [Train] Batch ID = 610, loss = 0.5494986, acc = 0.22
# [Validation] Batch ID = 610, loss = 0.5249658, acc = 0.2
# [Train] Batch ID = 620, loss = 0.49998486, acc = 0.3
# [Validation] Batch ID = 620, loss = 0.51110345, acc = 0.22
# [Train] Batch ID = 630, loss = 0.51838434, acc = 0.24
# [Validation] Batch ID = 630, loss = 0.51206094, acc = 0.26
# [Train] Batch ID = 640, loss = 0.5554491, acc = 0.2
# [Validation] Batch ID = 640, loss = 0.5133664, acc = 0.26
# [Train] Batch ID = 650, loss = 0.5315797, acc = 0.28
# [Validation] Batch ID = 650, loss = 0.5330945, acc = 0.2
# [Train] Batch ID = 660, loss = 0.518652, acc = 0.24
# [Validation] Batch ID = 660, loss = 0.51522887, acc = 0.36
# [Train] Batch ID = 670, loss = 0.52399313, acc = 0.28
# [Validation] Batch ID = 670, loss = 0.5007889, acc = 0.28
# [Train] Batch ID = 680, loss = 0.49183193, acc = 0.26
# [Validation] Batch ID = 680, loss = 0.5095907, acc = 0.3
# [Train] Batch ID = 690, loss = 0.53430945, acc = 0.2
# [Validation] Batch ID = 690, loss = 0.509171, acc = 0.3
# [Train] Batch ID = 700, loss = 0.5132444, acc = 0.26
# [Validation] Batch ID = 700, loss = 0.4963639, acc = 0.28
# [Train] Batch ID = 710, loss = 0.5138918, acc = 0.24
# [Validation] Batch ID = 710, loss = 0.44314668, acc = 0.34
# [Train] Batch ID = 720, loss = 0.54093057, acc = 0.16
# [Validation] Batch ID = 720, loss = 0.48110512, acc = 0.32
# [Train] Batch ID = 730, loss = 0.5620404, acc = 0.16
# [Validation] Batch ID = 730, loss = 0.53447235, acc = 0.26
# [Train] Batch ID = 740, loss = 0.5624607, acc = 0.12
# [Validation] Batch ID = 740, loss = 0.43114814, acc = 0.36
# [Train] Batch ID = 750, loss = 0.5476573, acc = 0.14
# [Validation] Batch ID = 750, loss = 0.476819, acc = 0.36
# [Train] Batch ID = 760, loss = 0.5352219, acc = 0.24
# [Validation] Batch ID = 760, loss = 0.48466536, acc = 0.3
# [Train] Batch ID = 770, loss = 0.5226618, acc = 0.26
# [Validation] Batch ID = 770, loss = 0.45079574, acc = 0.4
# [Train] Batch ID = 780, loss = 0.51873976, acc = 0.24
# [Validation] Batch ID = 780, loss = 0.4973525, acc = 0.3
# [Train] Batch ID = 790, loss = 0.53326154, acc = 0.26
# [Validation] Batch ID = 790, loss = 0.5448315, acc = 0.26
# [Train] Batch ID = 800, loss = 0.52082574, acc = 0.28
# [Validation] Batch ID = 800, loss = 0.34248453, acc = 0.7
# [Train] Batch ID = 810, loss = 0.51876444, acc = 0.26
# [Validation] Batch ID = 810, loss = 0.45186508, acc = 0.42
# [Train] Batch ID = 820, loss = 0.5467459, acc = 0.18
# [Validation] Batch ID = 820, loss = 0.44434342, acc = 0.42
# [Train] Batch ID = 830, loss = 0.51010966, acc = 0.38
# [Validation] Batch ID = 830, loss = 0.41056564, acc = 0.46
# [Train] Batch ID = 840, loss = 0.531956, acc = 0.2
# [Validation] Batch ID = 840, loss = 0.46889588, acc = 0.3
# [Train] Batch ID = 850, loss = 0.54192513, acc = 0.18
# [Validation] Batch ID = 850, loss = 0.4625098, acc = 0.3
# [Train] Batch ID = 860, loss = 0.5117868, acc = 0.36
# [Validation] Batch ID = 860, loss = 0.4953857, acc = 0.36
# [Train] Batch ID = 870, loss = 0.51345724, acc = 0.28
# [Validation] Batch ID = 870, loss = 0.45857972, acc = 0.4
# [Train] Batch ID = 880, loss = 0.51086307, acc = 0.28
# [Validation] Batch ID = 880, loss = 0.45190862, acc = 0.44
# [Train] Batch ID = 890, loss = 0.5437707, acc = 0.22
# [Validation] Batch ID = 890, loss = 0.413375, acc = 0.5
# [Train] Batch ID = 900, loss = 0.5305537, acc = 0.18
# [Validation] Batch ID = 900, loss = 0.41264975, acc = 0.38
# [Train] Batch ID = 910, loss = 0.4703793, acc = 0.36
# [Validation] Batch ID = 910, loss = 0.43887004, acc = 0.44
# [Train] Batch ID = 920, loss = 0.50637615, acc = 0.22
# [Validation] Batch ID = 920, loss = 0.44524026, acc = 0.32
# [Train] Batch ID = 930, loss = 0.45083663, acc = 0.36
# [Validation] Batch ID = 930, loss = 0.4406211, acc = 0.38
# [Train] Batch ID = 940, loss = 0.5630611, acc = 0.12
# [Validation] Batch ID = 940, loss = 0.42465973, acc = 0.48
# [Train] Batch ID = 950, loss = 0.48909995, acc = 0.38
# [Validation] Batch ID = 950, loss = 0.4366384, acc = 0.4
# [Train] Batch ID = 960, loss = 0.50630355, acc = 0.32
# [Validation] Batch ID = 960, loss = 0.46537417, acc = 0.36
# [Train] Batch ID = 970, loss = 0.47789234, acc = 0.32
# [Validation] Batch ID = 970, loss = 0.4641167, acc = 0.32
# [Train] Batch ID = 980, loss = 0.4028414, acc = 0.44
# [Validation] Batch ID = 980, loss = 0.46035287, acc = 0.34
# [Train] Batch ID = 990, loss = 0.43721786, acc = 0.42
# [Validation] Batch ID = 990, loss = 0.42934838, acc = 0.36
# [Train] Batch ID = 1000, loss = 0.49357292, acc = 0.24
# [Validation] Batch ID = 1000, loss = 0.43653175, acc = 0.44
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 0.43939695 Best loss: 1.7901701
# [TOTAL Validation] Batch ID = 1000, loss = 0.43939695, acc = 0.4043083900226757
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.8019000000000001
# [Train] Batch ID = 1010, loss = 0.458275, acc = 0.42
# [Validation] Batch ID = 1010, loss = 0.47747934, acc = 0.32
# [Train] Batch ID = 1020, loss = 0.40798593, acc = 0.5
# [Validation] Batch ID = 1020, loss = 0.3867901, acc = 0.48
# [Train] Batch ID = 1030, loss = 0.51089305, acc = 0.36
# [Validation] Batch ID = 1030, loss = 0.4338146, acc = 0.48
# [Train] Batch ID = 1040, loss = 0.5390472, acc = 0.18
# [Validation] Batch ID = 1040, loss = 0.42777523, acc = 0.42
# [Train] Batch ID = 1050, loss = 0.50556797, acc = 0.26
# [Validation] Batch ID = 1050, loss = 0.41131794, acc = 0.58
# [Train] Batch ID = 1060, loss = 0.5085166, acc = 0.26
# [Validation] Batch ID = 1060, loss = 0.44031006, acc = 0.42
# [Train] Batch ID = 1070, loss = 0.49394646, acc = 0.28
# [Validation] Batch ID = 1070, loss = 0.45098493, acc = 0.4
# [Train] Batch ID = 1080, loss = 0.4045416, acc = 0.56
# [Validation] Batch ID = 1080, loss = 0.42146522, acc = 0.42
# [Train] Batch ID = 1090, loss = 0.5136196, acc = 0.24
# [Validation] Batch ID = 1090, loss = 0.45176134, acc = 0.36
# [Train] Batch ID = 1100, loss = 0.49285, acc = 0.34
# [Validation] Batch ID = 1100, loss = 0.42155656, acc = 0.42
# [Train] Batch ID = 1110, loss = 0.47639123, acc = 0.32
# [Validation] Batch ID = 1110, loss = 0.41248065, acc = 0.46
# [Train] Batch ID = 1120, loss = 0.51506674, acc = 0.24
# [Validation] Batch ID = 1120, loss = 0.3852038, acc = 0.54
# [Train] Batch ID = 1130, loss = 0.4721601, acc = 0.42
# [Validation] Batch ID = 1130, loss = 0.4095215, acc = 0.48
# [Train] Batch ID = 1140, loss = 0.5023405, acc = 0.3
# [Validation] Batch ID = 1140, loss = 0.4056195, acc = 0.6
# [Train] Batch ID = 1150, loss = 0.3597675, acc = 0.62
# [Validation] Batch ID = 1150, loss = 0.36092168, acc = 0.6
# [Train] Batch ID = 1160, loss = 0.3865961, acc = 0.62
# [Validation] Batch ID = 1160, loss = 0.43050328, acc = 0.4
# [Train] Batch ID = 1170, loss = 0.4717575, acc = 0.5
# [Validation] Batch ID = 1170, loss = 0.401827, acc = 0.48
# [Train] Batch ID = 1180, loss = 0.511935, acc = 0.28
# [Validation] Batch ID = 1180, loss = 0.3952545, acc = 0.52
# [Train] Batch ID = 1190, loss = 0.45684677, acc = 0.3
# [Validation] Batch ID = 1190, loss = 0.41975173, acc = 0.42
# [Train] Batch ID = 1200, loss = 0.50636095, acc = 0.28
# [Validation] Batch ID = 1200, loss = 0.3811373, acc = 0.5
# [Train] Batch ID = 1210, loss = 0.48148862, acc = 0.32
# [Validation] Batch ID = 1210, loss = 0.41655937, acc = 0.38
# [Train] Batch ID = 1220, loss = 0.4883821, acc = 0.34
# [Validation] Batch ID = 1220, loss = 0.4076966, acc = 0.54
# [Train] Batch ID = 1230, loss = 0.4552371, acc = 0.4
# [Validation] Batch ID = 1230, loss = 0.37991875, acc = 0.52
# [Train] Batch ID = 1240, loss = 0.48405877, acc = 0.32
# [Validation] Batch ID = 1240, loss = 0.4179716, acc = 0.42
# [Train] Batch ID = 1250, loss = 0.49438304, acc = 0.26
# [Validation] Batch ID = 1250, loss = 0.40616456, acc = 0.48
# [Train] Batch ID = 1260, loss = 0.47385514, acc = 0.4
# [Validation] Batch ID = 1260, loss = 0.43568534, acc = 0.4
# [Train] Batch ID = 1270, loss = 0.46498206, acc = 0.46
# [Validation] Batch ID = 1270, loss = 0.45012733, acc = 0.4
# [Train] Batch ID = 1280, loss = 0.3721383, acc = 0.58
# [Validation] Batch ID = 1280, loss = 0.4226457, acc = 0.46
# [Train] Batch ID = 1290, loss = 0.3695067, acc = 0.58
# [Validation] Batch ID = 1290, loss = 0.3521243, acc = 0.6
# [Train] Batch ID = 1300, loss = 0.5132025, acc = 0.24
# [Validation] Batch ID = 1300, loss = 0.36963233, acc = 0.54
# [Train] Batch ID = 1310, loss = 0.4687106, acc = 0.42
# [Validation] Batch ID = 1310, loss = 0.34591687, acc = 0.64
# [Train] Batch ID = 1320, loss = 0.4838227, acc = 0.28
# [Validation] Batch ID = 1320, loss = 0.3943795, acc = 0.52
# [Train] Batch ID = 1330, loss = 0.35750094, acc = 0.66
# [Validation] Batch ID = 1330, loss = 0.40026724, acc = 0.5
# [Train] Batch ID = 1340, loss = 0.48094192, acc = 0.38
# [Validation] Batch ID = 1340, loss = 0.37605694, acc = 0.6
# [Train] Batch ID = 1350, loss = 0.44380292, acc = 0.44
# [Validation] Batch ID = 1350, loss = 0.37638992, acc = 0.64
# [Train] Batch ID = 1360, loss = 0.36536998, acc = 0.58
# [Validation] Batch ID = 1360, loss = 0.4068612, acc = 0.46
# [Train] Batch ID = 1370, loss = 0.46083558, acc = 0.32
# [Validation] Batch ID = 1370, loss = 0.33751824, acc = 0.58
# [Train] Batch ID = 1380, loss = 0.4677143, acc = 0.3
# [Validation] Batch ID = 1380, loss = 0.37490737, acc = 0.52
# [Train] Batch ID = 1390, loss = 0.46395278, acc = 0.4
# [Validation] Batch ID = 1390, loss = 0.3856846, acc = 0.5
# [Train] Batch ID = 1400, loss = 0.43719336, acc = 0.5
# [Validation] Batch ID = 1400, loss = 0.39116216, acc = 0.46
# [Train] Batch ID = 1410, loss = 0.45695063, acc = 0.4
# [Validation] Batch ID = 1410, loss = 0.4065802, acc = 0.4
# [Train] Batch ID = 1420, loss = 0.31736445, acc = 0.68
# [Validation] Batch ID = 1420, loss = 0.38421524, acc = 0.46
# [Train] Batch ID = 1430, loss = 0.49340013, acc = 0.32
# [Validation] Batch ID = 1430, loss = 0.3730174, acc = 0.52
# [Train] Batch ID = 1440, loss = 0.4820753, acc = 0.3
# [Validation] Batch ID = 1440, loss = 0.35408202, acc = 0.58
# [Train] Batch ID = 1450, loss = 0.33498466, acc = 0.54
# [Validation] Batch ID = 1450, loss = 0.3811778, acc = 0.48
# [Train] Batch ID = 1460, loss = 0.3355167, acc = 0.56
# [Validation] Batch ID = 1460, loss = 0.36774254, acc = 0.52
# [Train] Batch ID = 1470, loss = 0.47471318, acc = 0.3
# [Validation] Batch ID = 1470, loss = 0.37137824, acc = 0.54
# [Train] Batch ID = 1480, loss = 0.47505647, acc = 0.32
# [Validation] Batch ID = 1480, loss = 0.31633312, acc = 0.54
# [Train] Batch ID = 1490, loss = 0.48889464, acc = 0.38
# [Validation] Batch ID = 1490, loss = 0.36041874, acc = 0.5
# [Train] Batch ID = 1500, loss = 0.2943881, acc = 0.74
# [Validation] Batch ID = 1500, loss = 0.33171368, acc = 0.62
# [Train] Batch ID = 1510, loss = 0.5139897, acc = 0.28
# [Validation] Batch ID = 1510, loss = 0.35385773, acc = 0.68
# [Train] Batch ID = 1520, loss = 0.41716015, acc = 0.46
# [Validation] Batch ID = 1520, loss = 0.36440045, acc = 0.54
# [Train] Batch ID = 1530, loss = 0.46613201, acc = 0.34
# [Validation] Batch ID = 1530, loss = 0.33510986, acc = 0.56
# [Train] Batch ID = 1540, loss = 0.3207218, acc = 0.66
# [Validation] Batch ID = 1540, loss = 0.32784256, acc = 0.6
# [Train] Batch ID = 1550, loss = 0.49361, acc = 0.28
# [Validation] Batch ID = 1550, loss = 0.3544662, acc = 0.56
# [Train] Batch ID = 1560, loss = 0.4620884, acc = 0.36
# [Validation] Batch ID = 1560, loss = 0.3386277, acc = 0.56
# [Train] Batch ID = 1570, loss = 0.44897255, acc = 0.38
# [Validation] Batch ID = 1570, loss = 0.37983894, acc = 0.48
# [Train] Batch ID = 1580, loss = 0.4977841, acc = 0.24
# [Validation] Batch ID = 1580, loss = 0.3912189, acc = 0.46
# [Train] Batch ID = 1590, loss = 0.48425186, acc = 0.38
# [Validation] Batch ID = 1590, loss = 0.3730841, acc = 0.56
# [Train] Batch ID = 1600, loss = 0.47351864, acc = 0.38
# [Validation] Batch ID = 1600, loss = 0.30703944, acc = 0.68
# [Train] Batch ID = 1610, loss = 0.30576137, acc = 0.7
# [Validation] Batch ID = 1610, loss = 0.38694885, acc = 0.48
# [Train] Batch ID = 1620, loss = 0.4931109, acc = 0.34
# [Validation] Batch ID = 1620, loss = 0.31293973, acc = 0.68
# [Train] Batch ID = 1630, loss = 0.43328452, acc = 0.48
# [Validation] Batch ID = 1630, loss = 0.36670825, acc = 0.54
# [Train] Batch ID = 1640, loss = 0.47240192, acc = 0.38
# [Validation] Batch ID = 1640, loss = 0.33571696, acc = 0.66
# [Train] Batch ID = 1650, loss = 0.35681453, acc = 0.5
# [Validation] Batch ID = 1650, loss = 0.34248316, acc = 0.64
# [Train] Batch ID = 1660, loss = 0.4210557, acc = 0.46
# [Validation] Batch ID = 1660, loss = 0.3965077, acc = 0.44
# [Train] Batch ID = 1670, loss = 0.32106194, acc = 0.6
# [Validation] Batch ID = 1670, loss = 0.38316998, acc = 0.42
# [Train] Batch ID = 1680, loss = 0.33783844, acc = 0.52
# [Validation] Batch ID = 1680, loss = 0.37809655, acc = 0.6
# [Train] Batch ID = 1690, loss = 0.28368324, acc = 0.7
# [Validation] Batch ID = 1690, loss = 0.38256702, acc = 0.7
# [Train] Batch ID = 1700, loss = 0.42732766, acc = 0.5
# [Validation] Batch ID = 1700, loss = 0.36099663, acc = 0.44
# [Train] Batch ID = 1710, loss = 0.2772799, acc = 0.66
# [Validation] Batch ID = 1710, loss = 0.36425102, acc = 0.54
# [Train] Batch ID = 1720, loss = 0.4337105, acc = 0.48
# [Validation] Batch ID = 1720, loss = 0.34997296, acc = 0.64
# [Train] Batch ID = 1730, loss = 0.28175774, acc = 0.78
# [Validation] Batch ID = 1730, loss = 0.3141804, acc = 0.64
# [Train] Batch ID = 1740, loss = 0.3114277, acc = 0.58
# [Validation] Batch ID = 1740, loss = 0.3414327, acc = 0.68
# [Train] Batch ID = 1750, loss = 0.43727347, acc = 0.48
# [Validation] Batch ID = 1750, loss = 0.2993615, acc = 0.62
# [Train] Batch ID = 1760, loss = 0.4373879, acc = 0.36
# [Validation] Batch ID = 1760, loss = 0.2993219, acc = 0.68
# [Train] Batch ID = 1770, loss = 0.4954651, acc = 0.3
# [Validation] Batch ID = 1770, loss = 0.33578017, acc = 0.68
# [Train] Batch ID = 1780, loss = 0.26916426, acc = 0.8
# [Validation] Batch ID = 1780, loss = 0.31190917, acc = 0.66
# [Train] Batch ID = 1790, loss = 0.46781617, acc = 0.38
# [Validation] Batch ID = 1790, loss = 0.39757895, acc = 0.54
# [Train] Batch ID = 1800, loss = 0.31316712, acc = 0.6
# [Validation] Batch ID = 1800, loss = 0.34703296, acc = 0.54
# [Train] Batch ID = 1810, loss = 0.48400635, acc = 0.26
# [Validation] Batch ID = 1810, loss = 0.4032737, acc = 0.5
# [Train] Batch ID = 1820, loss = 0.30416855, acc = 0.74
# [Validation] Batch ID = 1820, loss = 0.34982353, acc = 0.5
# [Train] Batch ID = 1830, loss = 0.43807355, acc = 0.44
# [Validation] Batch ID = 1830, loss = 0.30881894, acc = 0.72
# [Train] Batch ID = 1840, loss = 0.46924132, acc = 0.34
# [Validation] Batch ID = 1840, loss = 0.33091363, acc = 0.58
# [Train] Batch ID = 1850, loss = 0.43230766, acc = 0.56
# [Validation] Batch ID = 1850, loss = 0.29032186, acc = 0.78
# [Train] Batch ID = 1860, loss = 0.48100448, acc = 0.28
# [Validation] Batch ID = 1860, loss = 0.35385668, acc = 0.56
# [Train] Batch ID = 1870, loss = 0.42813087, acc = 0.5
# [Validation] Batch ID = 1870, loss = 0.3635813, acc = 0.56
# [Train] Batch ID = 1880, loss = 0.4401985, acc = 0.38
# [Validation] Batch ID = 1880, loss = 0.2814167, acc = 0.7
# [Train] Batch ID = 1890, loss = 0.43300122, acc = 0.44
# [Validation] Batch ID = 1890, loss = 0.31280282, acc = 0.68
# [Train] Batch ID = 1900, loss = 0.43457603, acc = 0.46
# [Validation] Batch ID = 1900, loss = 0.34670052, acc = 0.58
# [Train] Batch ID = 1910, loss = 0.29928893, acc = 0.78
# [Validation] Batch ID = 1910, loss = 0.33462802, acc = 0.66
# [Train] Batch ID = 1920, loss = 0.27761775, acc = 0.8
# [Validation] Batch ID = 1920, loss = 0.34270176, acc = 0.56
# [Train] Batch ID = 1930, loss = 0.48275757, acc = 0.32
# [Validation] Batch ID = 1930, loss = 0.31763843, acc = 0.66
# [Train] Batch ID = 1940, loss = 0.46601012, acc = 0.34
# [Validation] Batch ID = 1940, loss = 0.31244376, acc = 0.6
# [Train] Batch ID = 1950, loss = 0.29381344, acc = 0.7
# [Validation] Batch ID = 1950, loss = 0.33580306, acc = 0.58
# [Train] Batch ID = 1960, loss = 0.45393425, acc = 0.36
# [Validation] Batch ID = 1960, loss = 0.34295338, acc = 0.68
# [Train] Batch ID = 1970, loss = 0.32182145, acc = 0.64
# [Validation] Batch ID = 1970, loss = 0.35184503, acc = 0.54
# [Train] Batch ID = 1980, loss = 0.2746984, acc = 0.82
# [Validation] Batch ID = 1980, loss = 0.304536, acc = 0.72
# [Train] Batch ID = 1990, loss = 0.47043225, acc = 0.34
# [Validation] Batch ID = 1990, loss = 0.32587293, acc = 0.64
# [Train] Batch ID = 2000, loss = 0.43863937, acc = 0.38
# [Validation] Batch ID = 2000, loss = 0.3109409, acc = 0.64
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 0.31470624 Best loss: 0.43939695
# [TOTAL Validation] Batch ID = 2000, loss = 0.31470624, acc = 0.6394557823129252
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.7217100000000001
# [Train] Batch ID = 2010, loss = 0.27134022, acc = 0.76
# [Validation] Batch ID = 2010, loss = 0.3536389, acc = 0.56
# [Train] Batch ID = 2020, loss = 0.42232797, acc = 0.38
# [Validation] Batch ID = 2020, loss = 0.35692224, acc = 0.52
# [Train] Batch ID = 2030, loss = 0.47394714, acc = 0.22
# [Validation] Batch ID = 2030, loss = 0.2908938, acc = 0.66
# [Train] Batch ID = 2040, loss = 0.44610488, acc = 0.46
# [Validation] Batch ID = 2040, loss = 0.3300766, acc = 0.62
# [Train] Batch ID = 2050, loss = 0.4653056, acc = 0.36
# [Validation] Batch ID = 2050, loss = 0.32184315, acc = 0.64
# [Train] Batch ID = 2060, loss = 0.45394558, acc = 0.46
# [Validation] Batch ID = 2060, loss = 0.26394367, acc = 0.78
# [Train] Batch ID = 2070, loss = 0.4404498, acc = 0.42
# [Validation] Batch ID = 2070, loss = 0.33984292, acc = 0.62
# [Train] Batch ID = 2080, loss = 0.28200895, acc = 0.78
# [Validation] Batch ID = 2080, loss = 0.28572837, acc = 0.7
# [Train] Batch ID = 2090, loss = 0.255531, acc = 0.84
# [Validation] Batch ID = 2090, loss = 0.30596507, acc = 0.66
# [Train] Batch ID = 2100, loss = 0.41299585, acc = 0.46
# [Validation] Batch ID = 2100, loss = 0.289405, acc = 0.64
# [Train] Batch ID = 2110, loss = 0.44144028, acc = 0.36
# [Validation] Batch ID = 2110, loss = 0.32484192, acc = 0.76
# [Train] Batch ID = 2120, loss = 0.45072162, acc = 0.44
# [Validation] Batch ID = 2120, loss = 0.33203286, acc = 0.5
# [Train] Batch ID = 2130, loss = 0.4735125, acc = 0.36
# [Validation] Batch ID = 2130, loss = 0.29789764, acc = 0.74
# [Train] Batch ID = 2140, loss = 0.27301618, acc = 0.74
# [Validation] Batch ID = 2140, loss = 0.30755264, acc = 0.66
# [Train] Batch ID = 2150, loss = 0.42194465, acc = 0.46
# [Validation] Batch ID = 2150, loss = 0.29870084, acc = 0.72
# [Train] Batch ID = 2160, loss = 0.4372281, acc = 0.42
# [Validation] Batch ID = 2160, loss = 0.29603305, acc = 0.64
# [Train] Batch ID = 2170, loss = 0.23865856, acc = 0.82
# [Validation] Batch ID = 2170, loss = 0.27494353, acc = 0.8
# [Train] Batch ID = 2180, loss = 0.43017358, acc = 0.4
# [Validation] Batch ID = 2180, loss = 0.2648517, acc = 0.84
# [Train] Batch ID = 2190, loss = 0.41648766, acc = 0.44
# [Validation] Batch ID = 2190, loss = 0.2852545, acc = 0.66
# [Train] Batch ID = 2200, loss = 0.281118, acc = 0.74
# [Validation] Batch ID = 2200, loss = 0.29694545, acc = 0.62
# [Train] Batch ID = 2210, loss = 0.45322677, acc = 0.4
# [Validation] Batch ID = 2210, loss = 0.34677556, acc = 0.58
# [Train] Batch ID = 2220, loss = 0.4418982, acc = 0.4
# [Validation] Batch ID = 2220, loss = 0.27734634, acc = 0.76
# [Train] Batch ID = 2230, loss = 0.44168755, acc = 0.42
# [Validation] Batch ID = 2230, loss = 0.32159474, acc = 0.64
# [Train] Batch ID = 2240, loss = 0.40404052, acc = 0.44
# [Validation] Batch ID = 2240, loss = 0.2899106, acc = 0.66
# [Train] Batch ID = 2250, loss = 0.42418805, acc = 0.44
# [Validation] Batch ID = 2250, loss = 0.31394893, acc = 0.66
# [Train] Batch ID = 2260, loss = 0.42258584, acc = 0.5
# [Validation] Batch ID = 2260, loss = 0.31538928, acc = 0.58
# [Train] Batch ID = 2270, loss = 0.40198037, acc = 0.48
# [Validation] Batch ID = 2270, loss = 0.28311223, acc = 0.68
# [Train] Batch ID = 2280, loss = 0.24067263, acc = 0.86
# [Validation] Batch ID = 2280, loss = 0.28420815, acc = 0.76
# [Train] Batch ID = 2290, loss = 0.43521872, acc = 0.48
# [Validation] Batch ID = 2290, loss = 0.27339104, acc = 0.78
# [Train] Batch ID = 2300, loss = 0.37156242, acc = 0.6
# [Validation] Batch ID = 2300, loss = 0.32793495, acc = 0.68
# [Train] Batch ID = 2310, loss = 0.4292463, acc = 0.46
# [Validation] Batch ID = 2310, loss = 0.2802644, acc = 0.74
# [Train] Batch ID = 2320, loss = 0.43018055, acc = 0.42
# [Validation] Batch ID = 2320, loss = 0.2868803, acc = 0.66
# [Train] Batch ID = 2330, loss = 0.383338, acc = 0.52
# [Validation] Batch ID = 2330, loss = 0.2890753, acc = 0.72
# [Train] Batch ID = 2340, loss = 0.24580212, acc = 0.74
# [Validation] Batch ID = 2340, loss = 0.25399452, acc = 0.8
# [Train] Batch ID = 2350, loss = 0.2781713, acc = 0.74
# [Validation] Batch ID = 2350, loss = 0.29058486, acc = 0.74
# [Train] Batch ID = 2360, loss = 0.46160176, acc = 0.44
# [Validation] Batch ID = 2360, loss = 0.26299936, acc = 0.74
# [Train] Batch ID = 2370, loss = 0.39603844, acc = 0.46
# [Validation] Batch ID = 2370, loss = 0.26592907, acc = 0.72
# [Train] Batch ID = 2380, loss = 0.22053596, acc = 0.88
# [Validation] Batch ID = 2380, loss = 0.2402612, acc = 0.82
# [Train] Batch ID = 2390, loss = 0.2441841, acc = 0.88
# [Validation] Batch ID = 2390, loss = 0.30787733, acc = 0.7
# [Train] Batch ID = 2400, loss = 0.2239869, acc = 0.8
# [Validation] Batch ID = 2400, loss = 0.27621034, acc = 0.74
# [Train] Batch ID = 2410, loss = 0.44294938, acc = 0.5
# [Validation] Batch ID = 2410, loss = 0.33305228, acc = 0.64
# [Train] Batch ID = 2420, loss = 0.43740204, acc = 0.44
# [Validation] Batch ID = 2420, loss = 0.25986508, acc = 0.8
# [Train] Batch ID = 2430, loss = 0.4198626, acc = 0.52
# [Validation] Batch ID = 2430, loss = 0.27297145, acc = 0.74
# [Train] Batch ID = 2440, loss = 0.44203582, acc = 0.44
# [Validation] Batch ID = 2440, loss = 0.25521004, acc = 0.68
# [Train] Batch ID = 2450, loss = 0.41351888, acc = 0.46
# [Validation] Batch ID = 2450, loss = 0.2711182, acc = 0.68
# [Train] Batch ID = 2460, loss = 0.23652357, acc = 0.76
# [Validation] Batch ID = 2460, loss = 0.27803558, acc = 0.72
# [Train] Batch ID = 2470, loss = 0.38880774, acc = 0.58
# [Validation] Batch ID = 2470, loss = 0.33825293, acc = 0.62
# [Train] Batch ID = 2480, loss = 0.37113693, acc = 0.5
# [Validation] Batch ID = 2480, loss = 0.24005665, acc = 0.78
# [Train] Batch ID = 2490, loss = 0.47014657, acc = 0.32
# [Validation] Batch ID = 2490, loss = 0.22018127, acc = 0.82
# [Train] Batch ID = 2500, loss = 0.4433947, acc = 0.34
# [Validation] Batch ID = 2500, loss = 0.2677488, acc = 0.66
# [Train] Batch ID = 2510, loss = 0.43424323, acc = 0.44
# [Validation] Batch ID = 2510, loss = 0.24556059, acc = 0.76
# [Train] Batch ID = 2520, loss = 0.39263204, acc = 0.54
# [Validation] Batch ID = 2520, loss = 0.23756649, acc = 0.82
# [Train] Batch ID = 2530, loss = 0.38162223, acc = 0.46
# [Validation] Batch ID = 2530, loss = 0.268177, acc = 0.7
# [Train] Batch ID = 2540, loss = 0.4281627, acc = 0.38
# [Validation] Batch ID = 2540, loss = 0.2698127, acc = 0.78
# [Train] Batch ID = 2550, loss = 0.46221828, acc = 0.42
# [Validation] Batch ID = 2550, loss = 0.32480514, acc = 0.66
# [Train] Batch ID = 2560, loss = 0.3692783, acc = 0.5510204
# [Validation] Batch ID = 2560, loss = 0.33202353, acc = 0.74
# [Train] Batch ID = 2570, loss = 0.47955742, acc = 0.32
# [Validation] Batch ID = 2570, loss = 0.22825247, acc = 0.78
# [Train] Batch ID = 2580, loss = 0.22185741, acc = 0.86
# [Validation] Batch ID = 2580, loss = 0.28785402, acc = 0.7
# [Train] Batch ID = 2590, loss = 0.40106565, acc = 0.52
# [Validation] Batch ID = 2590, loss = 0.30193305, acc = 0.68
# [Train] Batch ID = 2600, loss = 0.37979934, acc = 0.5
# [Validation] Batch ID = 2600, loss = 0.2493609, acc = 0.72
# [Train] Batch ID = 2610, loss = 0.3810299, acc = 0.5
# [Validation] Batch ID = 2610, loss = 0.27637166, acc = 0.74
# [Train] Batch ID = 2620, loss = 0.46617287, acc = 0.4
# [Validation] Batch ID = 2620, loss = 0.23011765, acc = 0.84
# [Train] Batch ID = 2630, loss = 0.40806884, acc = 0.46
# [Validation] Batch ID = 2630, loss = 0.24219184, acc = 0.68
# [Train] Batch ID = 2640, loss = 0.40719482, acc = 0.48
# [Validation] Batch ID = 2640, loss = 0.2582291, acc = 0.72
# [Train] Batch ID = 2650, loss = 0.4210803, acc = 0.46
# [Validation] Batch ID = 2650, loss = 0.29048726, acc = 0.7
# [Train] Batch ID = 2660, loss = 0.41865554, acc = 0.5
# [Validation] Batch ID = 2660, loss = 0.31266713, acc = 0.72
# [Train] Batch ID = 2670, loss = 0.4357521, acc = 0.46
# [Validation] Batch ID = 2670, loss = 0.29405418, acc = 0.64
# [Train] Batch ID = 2680, loss = 0.2492352, acc = 0.84
# [Validation] Batch ID = 2680, loss = 0.2997477, acc = 0.68
# [Train] Batch ID = 2690, loss = 0.39551246, acc = 0.52
# [Validation] Batch ID = 2690, loss = 0.28815445, acc = 0.78
# [Train] Batch ID = 2700, loss = 0.4631468, acc = 0.42
# [Validation] Batch ID = 2700, loss = 0.2496367, acc = 0.78
# [Train] Batch ID = 2710, loss = 0.40052977, acc = 0.44
# [Validation] Batch ID = 2710, loss = 0.26995212, acc = 0.76
# [Train] Batch ID = 2720, loss = 0.41923767, acc = 0.48
# [Validation] Batch ID = 2720, loss = 0.24420369, acc = 0.82
# [Train] Batch ID = 2730, loss = 0.37313396, acc = 0.62
# [Validation] Batch ID = 2730, loss = 0.21502732, acc = 0.84
# [Train] Batch ID = 2740, loss = 0.40197968, acc = 0.38
# [Validation] Batch ID = 2740, loss = 0.29202163, acc = 0.68
# [Train] Batch ID = 2750, loss = 0.2222959, acc = 0.84
# [Validation] Batch ID = 2750, loss = 0.23748352, acc = 0.76
# [Train] Batch ID = 2760, loss = 0.45573547, acc = 0.28
# [Validation] Batch ID = 2760, loss = 0.31121528, acc = 0.66
# [Train] Batch ID = 2770, loss = 0.48832297, acc = 0.3
# [Validation] Batch ID = 2770, loss = 0.30564618, acc = 0.76
# [Train] Batch ID = 2780, loss = 0.2338422, acc = 0.78
# [Validation] Batch ID = 2780, loss = 0.28606853, acc = 0.72
# [Train] Batch ID = 2790, loss = 0.4245058, acc = 0.4
# [Validation] Batch ID = 2790, loss = 0.25705218, acc = 0.82
# [Train] Batch ID = 2800, loss = 0.26131013, acc = 0.68
# [Validation] Batch ID = 2800, loss = 0.2812269, acc = 0.76
# [Train] Batch ID = 2810, loss = 0.39023072, acc = 0.58
# [Validation] Batch ID = 2810, loss = 0.25260854, acc = 0.7
# [Train] Batch ID = 2820, loss = 0.27936006, acc = 0.66
# [Validation] Batch ID = 2820, loss = 0.26459458, acc = 0.72
# [Train] Batch ID = 2830, loss = 0.2382982, acc = 0.8
# [Validation] Batch ID = 2830, loss = 0.2620874, acc = 0.66
# [Train] Batch ID = 2840, loss = 0.40437645, acc = 0.48
# [Validation] Batch ID = 2840, loss = 0.27717382, acc = 0.66
# [Train] Batch ID = 2850, loss = 0.40318376, acc = 0.52
# [Validation] Batch ID = 2850, loss = 0.26973394, acc = 0.78
# [Train] Batch ID = 2860, loss = 0.3815387, acc = 0.46
# [Validation] Batch ID = 2860, loss = 0.24989103, acc = 0.76
# [Train] Batch ID = 2870, loss = 0.39980903, acc = 0.52
# [Validation] Batch ID = 2870, loss = 0.23674496, acc = 0.78
# [Train] Batch ID = 2880, loss = 0.39098313, acc = 0.52
# [Validation] Batch ID = 2880, loss = 0.2505545, acc = 0.78
# [Train] Batch ID = 2890, loss = 0.3924067, acc = 0.46
# [Validation] Batch ID = 2890, loss = 0.26194412, acc = 0.72
# [Train] Batch ID = 2900, loss = 0.4025976, acc = 0.5
# [Validation] Batch ID = 2900, loss = 0.26816094, acc = 0.74
# [Train] Batch ID = 2910, loss = 0.4057762, acc = 0.46
# [Validation] Batch ID = 2910, loss = 0.31123027, acc = 0.64
# [Train] Batch ID = 2920, loss = 0.43079242, acc = 0.48
# [Validation] Batch ID = 2920, loss = 0.25606927, acc = 0.78
# [Train] Batch ID = 2930, loss = 0.4126149, acc = 0.42
# [Validation] Batch ID = 2930, loss = 0.25712028, acc = 0.74
# [Train] Batch ID = 2940, loss = 0.40990403, acc = 0.42
# [Validation] Batch ID = 2940, loss = 0.29252827, acc = 0.72
# [Train] Batch ID = 2950, loss = 0.20906167, acc = 0.82
# [Validation] Batch ID = 2950, loss = 0.26572645, acc = 0.76
# [Train] Batch ID = 2960, loss = 0.4292939, acc = 0.48
# [Validation] Batch ID = 2960, loss = 0.26039615, acc = 0.7
# [Train] Batch ID = 2970, loss = 0.21431404, acc = 0.88
# [Validation] Batch ID = 2970, loss = 0.26731923, acc = 0.76
# [Train] Batch ID = 2980, loss = 0.45352018, acc = 0.4
# [Validation] Batch ID = 2980, loss = 0.20462614, acc = 0.9
# [Train] Batch ID = 2990, loss = 0.20539837, acc = 0.86
# [Validation] Batch ID = 2990, loss = 0.26805168, acc = 0.74
# [Train] Batch ID = 3000, loss = 0.38941178, acc = 0.54
# [Validation] Batch ID = 3000, loss = 0.26220647, acc = 0.74
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 0.25164112 Best loss: 0.31470624
# [TOTAL Validation] Batch ID = 3000, loss = 0.25164112, acc = 0.7752834467120181
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.6495390000000001
# [Train] Batch ID = 3010, loss = 0.440033, acc = 0.44
# [Validation] Batch ID = 3010, loss = 0.29432783, acc = 0.74
# [Train] Batch ID = 3020, loss = 0.423295, acc = 0.44
# [Validation] Batch ID = 3020, loss = 0.23543145, acc = 0.82
# [Train] Batch ID = 3030, loss = 0.3699499, acc = 0.54
# [Validation] Batch ID = 3030, loss = 0.25596634, acc = 0.74
# [Train] Batch ID = 3040, loss = 0.3863969, acc = 0.56
# [Validation] Batch ID = 3040, loss = 0.28759426, acc = 0.76
# [Train] Batch ID = 3050, loss = 0.2525302, acc = 0.7
# [Validation] Batch ID = 3050, loss = 0.20873685, acc = 0.9
# [Train] Batch ID = 3060, loss = 0.3775757, acc = 0.54
# [Validation] Batch ID = 3060, loss = 0.27899835, acc = 0.7
# [Train] Batch ID = 3070, loss = 0.18148822, acc = 0.94
# [Validation] Batch ID = 3070, loss = 0.22430569, acc = 0.88
# [Train] Batch ID = 3080, loss = 0.42471394, acc = 0.46
# [Validation] Batch ID = 3080, loss = 0.23735975, acc = 0.82
# [Train] Batch ID = 3090, loss = 0.42244557, acc = 0.4
# [Validation] Batch ID = 3090, loss = 0.22376528, acc = 0.76
# [Train] Batch ID = 3100, loss = 0.41280708, acc = 0.48
# [Validation] Batch ID = 3100, loss = 0.20698124, acc = 0.88
# [Train] Batch ID = 3110, loss = 0.23681551, acc = 0.74
# [Validation] Batch ID = 3110, loss = 0.26395196, acc = 0.76
# [Train] Batch ID = 3120, loss = 0.22319604, acc = 0.86
# [Validation] Batch ID = 3120, loss = 0.2501341, acc = 0.76
# [Train] Batch ID = 3130, loss = 0.20732142, acc = 0.82
# [Validation] Batch ID = 3130, loss = 0.24743892, acc = 0.78
# [Train] Batch ID = 3140, loss = 0.24258232, acc = 0.82
# [Validation] Batch ID = 3140, loss = 0.26247227, acc = 0.74
# [Train] Batch ID = 3150, loss = 0.43315175, acc = 0.46
# [Validation] Batch ID = 3150, loss = 0.23993894, acc = 0.74
# [Train] Batch ID = 3160, loss = 0.39280808, acc = 0.48
# [Validation] Batch ID = 3160, loss = 0.25840518, acc = 0.78
# [Train] Batch ID = 3170, loss = 0.41491196, acc = 0.44
# [Validation] Batch ID = 3170, loss = 0.24550235, acc = 0.72
# [Train] Batch ID = 3180, loss = 0.43757114, acc = 0.5
# [Validation] Batch ID = 3180, loss = 0.22561257, acc = 0.78
# [Train] Batch ID = 3190, loss = 0.39210045, acc = 0.52
# [Validation] Batch ID = 3190, loss = 0.25031704, acc = 0.78
# [Train] Batch ID = 3200, loss = 0.18556273, acc = 0.94
# [Validation] Batch ID = 3200, loss = 0.20390543, acc = 0.88
# [Train] Batch ID = 3210, loss = 0.16644813, acc = 0.92
# [Validation] Batch ID = 3210, loss = 0.25536364, acc = 0.78
# [Train] Batch ID = 3220, loss = 0.3849012, acc = 0.54
# [Validation] Batch ID = 3220, loss = 0.2958103, acc = 0.66
# [Train] Batch ID = 3230, loss = 0.41348267, acc = 0.46
# [Validation] Batch ID = 3230, loss = 0.24828334, acc = 0.78
# [Train] Batch ID = 3240, loss = 0.23083729, acc = 0.82
# [Validation] Batch ID = 3240, loss = 0.24169281, acc = 0.8
# [Train] Batch ID = 3250, loss = 0.14997266, acc = 0.92
# [Validation] Batch ID = 3250, loss = 0.2739748, acc = 0.76
# [Train] Batch ID = 3260, loss = 0.36013559, acc = 0.6
# [Validation] Batch ID = 3260, loss = 0.19635004, acc = 0.86
# [Train] Batch ID = 3270, loss = 0.44149658, acc = 0.42
# [Validation] Batch ID = 3270, loss = 0.22050987, acc = 0.8
# [Train] Batch ID = 3280, loss = 0.14932455, acc = 0.9591837
# [Validation] Batch ID = 3280, loss = 0.2545436, acc = 0.78
# [Train] Batch ID = 3290, loss = 0.3780504, acc = 0.54
# [Validation] Batch ID = 3290, loss = 0.21579789, acc = 0.82
# [Train] Batch ID = 3300, loss = 0.16704398, acc = 0.94
# [Validation] Batch ID = 3300, loss = 0.20946161, acc = 0.88
# [Train] Batch ID = 3310, loss = 0.38417336, acc = 0.56
# [Validation] Batch ID = 3310, loss = 0.23951557, acc = 0.8
# [Train] Batch ID = 3320, loss = 0.3786956, acc = 0.5
# [Validation] Batch ID = 3320, loss = 0.20683588, acc = 0.86
# [Train] Batch ID = 3330, loss = 0.43478286, acc = 0.4
# [Validation] Batch ID = 3330, loss = 0.24993272, acc = 0.74
# [Train] Batch ID = 3340, loss = 0.37722167, acc = 0.56
# [Validation] Batch ID = 3340, loss = 0.23070538, acc = 0.78
# [Train] Batch ID = 3350, loss = 0.36825708, acc = 0.54
# [Validation] Batch ID = 3350, loss = 0.20848915, acc = 0.86
# [Train] Batch ID = 3360, loss = 0.42692506, acc = 0.38
# [Validation] Batch ID = 3360, loss = 0.25415084, acc = 0.76
# [Train] Batch ID = 3370, loss = 0.17762707, acc = 0.9
# [Validation] Batch ID = 3370, loss = 0.20604391, acc = 0.86
# [Train] Batch ID = 3380, loss = 0.14039189, acc = 0.92
# [Validation] Batch ID = 3380, loss = 0.25325117, acc = 0.7
# [Train] Batch ID = 3390, loss = 0.17229313, acc = 0.82
# [Validation] Batch ID = 3390, loss = 0.23899108, acc = 0.8
# [Train] Batch ID = 3400, loss = 0.15019049, acc = 0.96
# [Validation] Batch ID = 3400, loss = 0.27848426, acc = 0.7
# [Train] Batch ID = 3410, loss = 0.4017345, acc = 0.46
# [Validation] Batch ID = 3410, loss = 0.23546258, acc = 0.82
# [Train] Batch ID = 3420, loss = 0.20025139, acc = 0.8
# [Validation] Batch ID = 3420, loss = 0.21113266, acc = 0.9
# [Train] Batch ID = 3430, loss = 0.1783931, acc = 0.9
# [Validation] Batch ID = 3430, loss = 0.19076455, acc = 0.82
# [Train] Batch ID = 3440, loss = 0.40731865, acc = 0.48
# [Validation] Batch ID = 3440, loss = 0.21337067, acc = 0.88
# [Train] Batch ID = 3450, loss = 0.1949353, acc = 0.88
# [Validation] Batch ID = 3450, loss = 0.23870441, acc = 0.76
# [Train] Batch ID = 3460, loss = 0.17404586, acc = 0.92
# [Validation] Batch ID = 3460, loss = 0.23303364, acc = 0.76
# [Train] Batch ID = 3470, loss = 0.39867255, acc = 0.42
# [Validation] Batch ID = 3470, loss = 0.25895533, acc = 0.8
# [Train] Batch ID = 3480, loss = 0.42287013, acc = 0.36
# [Validation] Batch ID = 3480, loss = 0.18567447, acc = 0.9
# [Train] Batch ID = 3490, loss = 0.16540171, acc = 0.88
# [Validation] Batch ID = 3490, loss = 0.18862344, acc = 0.92
# [Train] Batch ID = 3500, loss = 0.21191038, acc = 0.9
# [Validation] Batch ID = 3500, loss = 0.23230267, acc = 0.86
# [Train] Batch ID = 3510, loss = 0.41422617, acc = 0.52
# [Validation] Batch ID = 3510, loss = 0.19852494, acc = 0.84
# [Train] Batch ID = 3520, loss = 0.37268323, acc = 0.56
# [Validation] Batch ID = 3520, loss = 0.22957385, acc = 0.76
# [Train] Batch ID = 3530, loss = 0.175252, acc = 0.9
# [Validation] Batch ID = 3530, loss = 0.24006838, acc = 0.82
# [Train] Batch ID = 3540, loss = 0.16630638, acc = 0.96
# [Validation] Batch ID = 3540, loss = 0.19609265, acc = 0.86
# [Train] Batch ID = 3550, loss = 0.33833295, acc = 0.62
# [Validation] Batch ID = 3550, loss = 0.22265682, acc = 0.86
# [Train] Batch ID = 3560, loss = 0.40846244, acc = 0.5
# [Validation] Batch ID = 3560, loss = 0.26589358, acc = 0.78
# [Train] Batch ID = 3570, loss = 0.16664219, acc = 0.96
# [Validation] Batch ID = 3570, loss = 0.2312632, acc = 0.76
# [Train] Batch ID = 3580, loss = 0.39487687, acc = 0.4
# [Validation] Batch ID = 3580, loss = 0.23526374, acc = 0.76
# [Train] Batch ID = 3590, loss = 0.4296561, acc = 0.42857143
# [Validation] Batch ID = 3590, loss = 0.20226263, acc = 0.86
# [Train] Batch ID = 3600, loss = 0.39490464, acc = 0.62
# [Validation] Batch ID = 3600, loss = 0.1877829, acc = 0.86
# [Train] Batch ID = 3610, loss = 0.13603872, acc = 1.0
# [Validation] Batch ID = 3610, loss = 0.20397988, acc = 0.88
# [Train] Batch ID = 3620, loss = 0.4023364, acc = 0.54
# [Validation] Batch ID = 3620, loss = 0.16014011, acc = 0.9
# [Train] Batch ID = 3630, loss = 0.40857795, acc = 0.52
# [Validation] Batch ID = 3630, loss = 0.22677757, acc = 0.86
# [Train] Batch ID = 3640, loss = 0.39093482, acc = 0.46
# [Validation] Batch ID = 3640, loss = 0.24825455, acc = 0.78
# [Train] Batch ID = 3650, loss = 0.14552453, acc = 0.96
# [Validation] Batch ID = 3650, loss = 0.24017948, acc = 0.74
# [Train] Batch ID = 3660, loss = 0.34491566, acc = 0.66
# [Validation] Batch ID = 3660, loss = 0.2041021, acc = 0.82
# [Train] Batch ID = 3670, loss = 0.17508964, acc = 0.96
# [Validation] Batch ID = 3670, loss = 0.19415268, acc = 0.82
# [Train] Batch ID = 3680, loss = 0.16929397, acc = 0.94
# [Validation] Batch ID = 3680, loss = 0.20456497, acc = 0.84
# [Train] Batch ID = 3690, loss = 0.1979219, acc = 0.88
# [Validation] Batch ID = 3690, loss = 0.19623756, acc = 0.88
# [Train] Batch ID = 3700, loss = 0.41612232, acc = 0.42
# [Validation] Batch ID = 3700, loss = 0.22651398, acc = 0.8
# [Train] Batch ID = 3710, loss = 0.43852675, acc = 0.5
# [Validation] Batch ID = 3710, loss = 0.18639356, acc = 0.86
# [Train] Batch ID = 3720, loss = 0.18380776, acc = 0.86
# [Validation] Batch ID = 3720, loss = 0.21737462, acc = 0.74
# [Train] Batch ID = 3730, loss = 0.39520395, acc = 0.5
# [Validation] Batch ID = 3730, loss = 0.23519298, acc = 0.82
# [Train] Batch ID = 3740, loss = 0.42797527, acc = 0.44
# [Validation] Batch ID = 3740, loss = 0.20861381, acc = 0.8
# [Train] Batch ID = 3750, loss = 0.14355844, acc = 0.96
# [Validation] Batch ID = 3750, loss = 0.18355447, acc = 0.88
# [Train] Batch ID = 3760, loss = 0.4385089, acc = 0.36
# [Validation] Batch ID = 3760, loss = 0.20254189, acc = 0.84
# [Train] Batch ID = 3770, loss = 0.4158628, acc = 0.5
# [Validation] Batch ID = 3770, loss = 0.22831897, acc = 0.8
# [Train] Batch ID = 3780, loss = 0.3948413, acc = 0.52
# [Validation] Batch ID = 3780, loss = 0.21066521, acc = 0.82
# [Train] Batch ID = 3790, loss = 0.15121835, acc = 0.92
# [Validation] Batch ID = 3790, loss = 0.19135197, acc = 0.86
# [Train] Batch ID = 3800, loss = 0.41372725, acc = 0.4
# [Validation] Batch ID = 3800, loss = 0.21120076, acc = 0.76
# [Train] Batch ID = 3810, loss = 0.1548015, acc = 0.98
# [Validation] Batch ID = 3810, loss = 0.17383522, acc = 0.86
# [Train] Batch ID = 3820, loss = 0.40077046, acc = 0.58
# [Validation] Batch ID = 3820, loss = 0.20786068, acc = 0.84
# [Train] Batch ID = 3830, loss = 0.15788206, acc = 0.94
# [Validation] Batch ID = 3830, loss = 0.188673, acc = 0.84
# [Train] Batch ID = 3840, loss = 0.1747404, acc = 0.92
# [Validation] Batch ID = 3840, loss = 0.20438753, acc = 0.82
# [Train] Batch ID = 3850, loss = 0.41136837, acc = 0.48
# [Validation] Batch ID = 3850, loss = 0.23143624, acc = 0.8
# [Train] Batch ID = 3860, loss = 0.41022122, acc = 0.52
# [Validation] Batch ID = 3860, loss = 0.21537971, acc = 0.76
# [Train] Batch ID = 3870, loss = 0.40744054, acc = 0.46
# [Validation] Batch ID = 3870, loss = 0.16737576, acc = 0.92
# [Train] Batch ID = 3880, loss = 0.38534355, acc = 0.44
# [Validation] Batch ID = 3880, loss = 0.18532489, acc = 0.92
# [Train] Batch ID = 3890, loss = 0.18011749, acc = 0.88
# [Validation] Batch ID = 3890, loss = 0.22225416, acc = 0.8
# [Train] Batch ID = 3900, loss = 0.1735944, acc = 0.86
# [Validation] Batch ID = 3900, loss = 0.21571304, acc = 0.82
# [Train] Batch ID = 3910, loss = 0.37379098, acc = 0.52
# [Validation] Batch ID = 3910, loss = 0.22688694, acc = 0.74
# [Train] Batch ID = 3920, loss = 0.18402489, acc = 0.86
# [Validation] Batch ID = 3920, loss = 0.18236585, acc = 0.8
# [Train] Batch ID = 3930, loss = 0.3633187, acc = 0.54
# [Validation] Batch ID = 3930, loss = 0.22467774, acc = 0.84
# [Train] Batch ID = 3940, loss = 0.3509809, acc = 0.6
# [Validation] Batch ID = 3940, loss = 0.20992287, acc = 0.78
# [Train] Batch ID = 3950, loss = 0.3696865, acc = 0.56
# [Validation] Batch ID = 3950, loss = 0.1921653, acc = 0.8
# [Train] Batch ID = 3960, loss = 0.38977677, acc = 0.56
# [Validation] Batch ID = 3960, loss = 0.19910838, acc = 0.86
# [Train] Batch ID = 3970, loss = 0.4055409, acc = 0.46
# [Validation] Batch ID = 3970, loss = 0.16564548, acc = 0.9
# [Train] Batch ID = 3980, loss = 0.16805637, acc = 0.94
# [Validation] Batch ID = 3980, loss = 0.18504864, acc = 0.92
# [Train] Batch ID = 3990, loss = 0.18873051, acc = 0.8
# [Validation] Batch ID = 3990, loss = 0.18977378, acc = 0.8
# [Train] Batch ID = 4000, loss = 0.16874035, acc = 0.86
# [Validation] Batch ID = 4000, loss = 0.22460726, acc = 0.82
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 0.20493424 Best loss: 0.25164112
# [TOTAL Validation] Batch ID = 4000, loss = 0.20493424, acc = 0.8360544217687075
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.5845851000000001
# [Train] Batch ID = 4010, loss = 0.3912593, acc = 0.6
# [Validation] Batch ID = 4010, loss = 0.19274077, acc = 0.88
# [Train] Batch ID = 4020, loss = 0.40743285, acc = 0.46
# [Validation] Batch ID = 4020, loss = 0.21632038, acc = 0.8
# [Train] Batch ID = 4030, loss = 0.42635354, acc = 0.5
# [Validation] Batch ID = 4030, loss = 0.25001606, acc = 0.78
# [Train] Batch ID = 4040, loss = 0.428104, acc = 0.42
# [Validation] Batch ID = 4040, loss = 0.20302631, acc = 0.84
# [Train] Batch ID = 4050, loss = 0.15307155, acc = 0.94
# ...
# [Validation] Batch ID = 8640, loss = 0.07446147, acc = 0.98
# [Train] Batch ID = 8650, loss = 0.0676421, acc = 0.96
# [Validation] Batch ID = 8650, loss = 0.08483765, acc = 0.96
# [Train] Batch ID = 8660, loss = 0.31413576, acc = 0.7
# [Validation] Batch ID = 8660, loss = 0.08064303, acc = 0.94
# [Train] Batch ID = 8670, loss = 0.04861332, acc = 0.98
# [Validation] Batch ID = 8670, loss = 0.12903763, acc = 0.88
# [Train] Batch ID = 8680, loss = 0.037377417, acc = 1.0
# [Validation] Batch ID = 8680, loss = 0.06340089, acc = 0.98
# [Train] Batch ID = 8690, loss = 0.29116768, acc = 0.72
# [Validation] Batch ID = 8690, loss = 0.055960197, acc = 1.0
# [Train] Batch ID = 8700, loss = 0.042531118, acc = 0.98
# [Validation] Batch ID = 8700, loss = 0.073463954, acc = 1.0
# [Train] Batch ID = 8710, loss = 0.27333334, acc = 0.74
# [Validation] Batch ID = 8710, loss = 0.06788736, acc = 0.98
# [Train] Batch ID = 8720, loss = 0.26516777, acc = 0.74
# [Validation] Batch ID = 8720, loss = 0.089277, acc = 0.94
# [Train] Batch ID = 8730, loss = 0.039871722, acc = 1.0
# [Validation] Batch ID = 8730, loss = 0.06496689, acc = 1.0
# [Train] Batch ID = 8740, loss = 0.28042972, acc = 0.74
# [Validation] Batch ID = 8740, loss = 0.09444683, acc = 0.98
# [Train] Batch ID = 8750, loss = 0.036327723, acc = 1.0
# [Validation] Batch ID = 8750, loss = 0.10928177, acc = 0.94
# [Train] Batch ID = 8760, loss = 0.36313993, acc = 0.5
# [Validation] Batch ID = 8760, loss = 0.1068845, acc = 0.92
# [Train] Batch ID = 8770, loss = 0.298672, acc = 0.78
# [Validation] Batch ID = 8770, loss = 0.07520758, acc = 0.98
# [Train] Batch ID = 8780, loss = 0.04384237, acc = 1.0
# [Validation] Batch ID = 8780, loss = 0.06987849, acc = 0.96
# [Train] Batch ID = 8790, loss = 0.25027633, acc = 0.72
# [Validation] Batch ID = 8790, loss = 0.080323696, acc = 0.94
# [Train] Batch ID = 8800, loss = 0.27051574, acc = 0.76
# [Validation] Batch ID = 8800, loss = 0.07949324, acc = 0.96
# [Train] Batch ID = 8810, loss = 0.033790074, acc = 1.0
# [Validation] Batch ID = 8810, loss = 0.05169192, acc = 1.0
# [Train] Batch ID = 8820, loss = 0.04433424, acc = 1.0
# [Validation] Batch ID = 8820, loss = 0.06183801, acc = 1.0
# [Train] Batch ID = 8830, loss = 0.027006079, acc = 1.0
# [Validation] Batch ID = 8830, loss = 0.06191205, acc = 1.0
# [Train] Batch ID = 8840, loss = 0.29815137, acc = 0.7
# [Validation] Batch ID = 8840, loss = 0.059536867, acc = 0.96
# [Train] Batch ID = 8850, loss = 0.28318998, acc = 0.8
# [Validation] Batch ID = 8850, loss = 0.11724802, acc = 0.96
# [Train] Batch ID = 8860, loss = 0.27859843, acc = 0.74
# [Validation] Batch ID = 8860, loss = 0.06481093, acc = 0.98
# [Train] Batch ID = 8870, loss = 0.039496947, acc = 1.0
# [Validation] Batch ID = 8870, loss = 0.07739676, acc = 0.96
# [Train] Batch ID = 8880, loss = 0.046496134, acc = 1.0
# [Validation] Batch ID = 8880, loss = 0.1188656, acc = 0.88
# [Train] Batch ID = 8890, loss = 0.04085015, acc = 1.0
# [Validation] Batch ID = 8890, loss = 0.098269634, acc = 0.9
# [Train] Batch ID = 8900, loss = 0.053115305, acc = 0.96
# [Validation] Batch ID = 8900, loss = 0.11981134, acc = 0.92
# [Train] Batch ID = 8910, loss = 0.03426459, acc = 1.0
# [Validation] Batch ID = 8910, loss = 0.107363895, acc = 0.92
# [Train] Batch ID = 8920, loss = 0.039474633, acc = 0.98
# [Validation] Batch ID = 8920, loss = 0.08331332, acc = 0.98
# [Train] Batch ID = 8930, loss = 0.24418136, acc = 0.76
# [Validation] Batch ID = 8930, loss = 0.06654173, acc = 0.96
# [Train] Batch ID = 8940, loss = 0.24919257, acc = 0.74
# [Validation] Batch ID = 8940, loss = 0.08223465, acc = 0.92
# [Train] Batch ID = 8950, loss = 0.04751396, acc = 0.98
# [Validation] Batch ID = 8950, loss = 0.08606298, acc = 0.94
# [Train] Batch ID = 8960, loss = 0.034799643, acc = 1.0
# [Validation] Batch ID = 8960, loss = 0.0818268, acc = 0.96
# [Train] Batch ID = 8970, loss = 0.29363275, acc = 0.74
# [Validation] Batch ID = 8970, loss = 0.08059277, acc = 0.94
# [Train] Batch ID = 8980, loss = 0.30625367, acc = 0.68
# [Validation] Batch ID = 8980, loss = 0.048997164, acc = 1.0
# [Train] Batch ID = 8990, loss = 0.042105313, acc = 1.0
# [Validation] Batch ID = 8990, loss = 0.1109983, acc = 0.92
# [Train] Batch ID = 9000, loss = 0.03440012, acc = 1.0
# [Validation] Batch ID = 9000, loss = 0.07388569, acc = 0.94
# Evaluate full validation dataset ...
# ModelBase::Saving model ...
# Current loss: 0.0809525 Best loss: 0.08972348
# [TOTAL Validation] Batch ID = 9000, loss = 0.0809525, acc = 0.953514739229025
# ModelBase::Model successfully saved here: outputs/checkpoints/c1s_9_c1n_256_c2s_6_c2n_64_c2d_0.7_c1vl_16_c1s_5_c1nf_16_c2vl_32_lr_0.0001_rs_1--TrafficSign--1572435967.4211385
# Augmented Factor = 0.34519165569900007
# [Train] Batch ID = 9010, loss = 0.03943084, acc = 1.0
# [Validation] Batch ID = 9010, loss = 0.075000204, acc = 0.98
# [Train] Batch ID = 9020, loss = 0.24500331, acc = 0.8
# [Validation] Batch ID = 9020, loss = 0.08813539, acc = 0.94
# [Train] Batch ID = 9030, loss = 0.02851931, acc = 1.0
# [Validation] Batch ID = 9030, loss = 0.040329743, acc = 1.0
# [Train] Batch ID = 9040, loss = 0.28516698, acc = 0.72
# [Validation] Batch ID = 9040, loss = 0.06436644, acc = 0.98
# [Train] Batch ID = 9050, loss = 0.04338747, acc = 1.0
# [Validation] Batch ID = 9050, loss = 0.06373141, acc = 0.98
# [Train] Batch ID = 9060, loss = 0.28846043, acc = 0.74
# [Validation] Batch ID = 9060, loss = 0.074741736, acc = 0.96
# [Train] Batch ID = 9070, loss = 0.05492875, acc = 0.98
# [Validation] Batch ID = 9070, loss = 0.069009624, acc = 0.98
# [Train] Batch ID = 9080, loss = 0.034724925, acc = 1.0
# [Validation] Batch ID = 9080, loss = 0.06422486, acc = 0.98
# [Train] Batch ID = 9090, loss = 0.31002098, acc = 0.64
# [Validation] Batch ID = 9090, loss = 0.08033588, acc = 0.98
# [Train] Batch ID = 9100, loss = 0.04756455, acc = 1.0
# [Validation] Batch ID = 9100, loss = 0.08279821, acc = 0.94
# [Train] Batch ID = 9110, loss = 0.25241673, acc = 0.68
# [Validation] Batch ID = 9110, loss = 0.068942726, acc = 0.96
# [Train] Batch ID = 9120, loss = 0.22802563, acc = 0.76
# [Validation] Batch ID = 9120, loss = 0.09021197, acc = 0.96
# [Train] Batch ID = 9130, loss = 0.037317485, acc = 1.0
# [Validation] Batch ID = 9130, loss = 0.08700579, acc = 0.92
# [Train] Batch ID = 9140, loss = 0.27847224, acc = 0.7
# [Validation] Batch ID = 9140, loss = 0.08636462, acc = 0.96
# [Train] Batch ID = 9150, loss = 0.04600046, acc = 0.96
# [Validation] Batch ID = 9150, loss = 0.08652027, acc = 0.92
# [Train] Batch ID = 9160, loss = 0.043427955, acc = 1.0
# [Validation] Batch ID = 9160, loss = 0.08286768, acc = 0.94
# [Train] Batch ID = 9170, loss = 0.040092275, acc = 1.0
# [Validation] Batch ID = 9170, loss = 0.11680192, acc = 0.9
# [Train] Batch ID = 9180, loss = 0.29766223, acc = 0.62
# [Validation] Batch ID = 9180, loss = 0.09839245, acc = 0.94
# [Train] Batch ID = 9190, loss = 0.2996713, acc = 0.72
# [Validation] Batch ID = 9190, loss = 0.05383933, acc = 0.98
# [Train] Batch ID = 9200, loss = 0.044340577, acc = 0.98
# [Validation] Batch ID = 9200, loss = 0.09447172, acc = 0.92
# [Train] Batch ID = 9210, loss = 0.22035015, acc = 0.82
# [Validation] Batch ID = 9210, loss = 0.08231841, acc = 0.96
# [Train] Batch ID = 9220, loss = 0.03793595, acc = 0.98
# [Validation] Batch ID = 9220, loss = 0.06684788, acc = 0.98
# [Train] Batch ID = 9230, loss = 0.035602257, acc = 1.0
# [Validation] Batch ID = 9230, loss = 0.08160004, acc = 0.96
# [Train] Batch ID = 9240, loss = 0.27530462, acc = 0.68
# [Validation] Batch ID = 9240, loss = 0.07455285, acc = 0.96
# [Train] Batch ID = 9250, loss = 0.04909978, acc = 1.0
# [Validation] Batch ID = 9250, loss = 0.0746906, acc = 0.96
# [Train] Batch ID = 9260, loss = 0.04325674, acc = 1.0
# [Validation] Batch ID = 9260, loss = 0.05938906, acc = 1.0
# [Train] Batch ID = 9270, loss = 0.02854297, acc = 0.98
# [Validation] Batch ID = 9270, loss = 0.06995354, acc = 0.96
# [Train] Batch ID = 9280, loss = 0.28417537, acc = 0.64
# [Validation] Batch ID = 9280, loss = 0.0978856, acc = 0.92
# [Train] Batch ID = 9290, loss = 0.29696894, acc = 0.7
# [Validation] Batch ID = 9290, loss = 0.08518335, acc = 0.96
# [Train] Batch ID = 9300, loss = 0.27205572, acc = 0.8
# [Validation] Batch ID = 9300, loss = 0.07902024, acc = 0.96
# [Train] Batch ID = 9310, loss = 0.044345785, acc = 1.0
# [Validation] Batch ID = 9310, loss = 0.087233305, acc = 0.88
# [Train] Batch ID = 9320, loss = 0.26721868, acc = 0.72
# [Validation] Batch ID = 9320, loss = 0.062385615, acc = 0.98
# [Train] Batch ID = 9330, loss = 0.03205364, acc = 1.0
# [Validation] Batch ID = 9330, loss = 0.103844315, acc = 0.94
# [Train] Batch ID = 9340, loss = 0.036786065, acc = 1.0
# [Validation] Batch ID = 9340, loss = 0.07605156, acc = 0.94
# [Train] Batch ID = 9350, loss = 0.046784345, acc = 0.98
# [Validation] Batch ID = 9350, loss = 0.061013985, acc = 0.98
# [Train] Batch ID = 9360, loss = 0.054035295, acc = 0.98
# [Validation] Batch ID = 9360, loss = 0.06866206, acc = 0.96
# [Train] Batch ID = 9370, loss = 0.031230817, acc = 1.0
# [Validation] Batch ID = 9370, loss = 0.070733726, acc = 0.96
# [Train] Batch ID = 9380, loss = 0.30193081, acc = 0.72
# [Validation] Batch ID = 9380, loss = 0.048750497, acc = 1.0
# [Train] Batch ID = 9390, loss = 0.03894263, acc = 1.0
# [Validation] Batch ID = 9390, loss = 0.09423459, acc = 0.94
# [Train] Batch ID = 9400, loss = 0.03367573, acc = 1.0
# [Validation] Batch ID = 9400, loss = 0.068494186, acc = 0.98
# [Train] Batch ID = 9410, loss = 0.032835945, acc = 1.0
# [Validation] Batch ID = 9410, loss = 0.09855495, acc = 0.96
# [Train] Batch ID = 9420, loss = 0.039039597, acc = 1.0
# [Validation] Batch ID = 9420, loss = 0.103170305, acc = 0.92
# [Train] Batch ID = 9430, loss = 0.04461009, acc = 1.0
# [Validation] Batch ID = 9430, loss = 0.09682468, acc = 0.94
# [Train] Batch ID = 9440, loss = 0.035694856, acc = 1.0
# [Validation] Batch ID = 9440, loss = 0.07623842, acc = 0.96
# [Train] Batch ID = 9450, loss = 0.050607804, acc = 1.0
# [Validation] Batch ID = 9450, loss = 0.06574502, acc = 0.96
# [Train] Batch ID = 9460, loss = 0.314603, acc = 0.72
# [Validation] Batch ID = 9460, loss = 0.0951859, acc = 0.96
# [Train] Batch ID = 9470, loss = 0.30957884, acc = 0.7
# [Validation] Batch ID = 9470, loss = 0.07754523, acc = 0.92
# [Train] Batch ID = 9480, loss = 0.031192487, acc = 1.0
# [Validation] Batch ID = 9480, loss = 0.09843687, acc = 0.96
# [Train] Batch ID = 9490, loss = 0.25674766, acc = 0.76
# [Validation] Batch ID = 9490, loss = 0.061541688, acc = 0.98
# [Train] Batch ID = 9500, loss = 0.034414, acc = 1.0
# [Validation] Batch ID = 9500, loss = 0.06970066, acc = 0.96
# [Train] Batch ID = 9510, loss = 0.29319218, acc = 0.62
# [Validation] Batch ID = 9510, loss = 0.064455755, acc = 0.94
# [Train] Batch ID = 9520, loss = 0.022521144, acc = 1.0
# [Validation] Batch ID = 9520, loss = 0.06924825, acc = 0.96
# [Train] Batch ID = 9530, loss = 0.24221112, acc = 0.76
# [Validation] Batch ID = 9530, loss = 0.07877753, acc = 0.96
# [Train] Batch ID = 9540, loss = 0.045920018, acc = 0.98
# [Validation] Batch ID = 9540, loss = 0.09061475, acc = 0.94
# [Train] Batch ID = 9550, loss = 0.041978493, acc = 1.0
# [Validation] Batch ID = 9550, loss = 0.09185477, acc = 0.98
# [Train] Batch ID = 9560, loss = 0.28117818, acc = 0.66
# [Validation] Batch ID = 9560, loss = 0.07570995, acc = 0.98
# [Train] Batch ID = 9570, loss = 0.027752647, acc = 1.0
# [Validation] Batch ID = 9570, loss = 0.061385185, acc = 1.0
# [Train] Batch ID = 9580, loss = 0.26631084, acc = 0.7
# [Validation] Batch ID = 9580, loss = 0.05953561, acc = 1.0
# [Train] Batch ID = 9590, loss = 0.048523802, acc = 1.0
# [Validation] Batch ID = 9590, loss = 0.076129854, acc = 0.96
# [Train] Batch ID = 9600, loss = 0.05193251, acc = 0.96
# [Validation] Batch ID = 9600, loss = 0.04337636, acc = 0.98
# [Train] Batch ID = 9610, loss = 0.0574448, acc = 0.98
# [Validation] Batch ID = 9610, loss = 0.07964679, acc = 1.0
# [Train] Batch ID = 9620, loss = 0.2987255, acc = 0.68
# [Validation] Batch ID = 9620, loss = 0.06289318, acc = 0.96
# [Train] Batch ID = 9630, loss = 0.27552247, acc = 0.74
# [Validation] Batch ID = 9630, loss = 0.09936846, acc = 0.96
# [Train] Batch ID = 9640, loss = 0.27175373, acc = 0.68
# [Validation] Batch ID = 9640, loss = 0.07620118, acc = 0.92
# [Train] Batch ID = 9650, loss = 0.029655121, acc = 1.0
# [Validation] Batch ID = 9650, loss = 0.06727714, acc = 0.98
# [Train] Batch ID = 9660, loss = 0.03730902, acc = 1.0
# [Validation] Batch ID = 9660, loss = 0.07198419, acc = 0.96
# [Train] Batch ID = 9670, loss = 0.026370468, acc = 1.0
# [Validation] Batch ID = 9670, loss = 0.07603324, acc = 0.94
# [Train] Batch ID = 9680, loss = 0.033470362, acc = 1.0
# [Validation] Batch ID = 9680, loss = 0.09159171, acc = 0.92
# [Train] Batch ID = 9690, loss = 0.021987438, acc = 1.0
# [Validation] Batch ID = 9690, loss = 0.105406344, acc = 0.92
# [Train] Batch ID = 9700, loss = 0.03481141, acc = 1.0
# [Validation] Batch ID = 9700, loss = 0.042401977, acc = 1.0
# [Train] Batch ID = 9710, loss = 0.28577113, acc = 0.7
# [Validation] Batch ID = 9710, loss = 0.063358895, acc = 0.98
# [Train] Batch ID = 9720, loss = 0.027897006, acc = 1.0
# [Validation] Batch ID = 9720, loss = 0.10052969, acc = 0.9
# [Train] Batch ID = 9730, loss = 0.046921954, acc = 0.98
# [Validation] Batch ID = 9730, loss = 0.051146947, acc = 1.0
# [Train] Batch ID = 9740, loss = 0.035136342, acc = 1.0
# [Validation] Batch ID = 9740, loss = 0.05454369, acc = 0.98
# [Train] Batch ID = 9750, loss = 0.29285944, acc = 0.76
# [Validation] Batch ID = 9750, loss = 0.07496138, acc = 0.98
# [Train] Batch ID = 9760, loss = 0.046098948, acc = 1.0
# [Validation] Batch ID = 9760, loss = 0.09626638, acc = 0.92
# [Train] Batch ID = 9770, loss = 0.03816382, acc = 1.0
# [Validation] Batch ID = 9770, loss = 0.07798938, acc = 0.94
# [Train] Batch ID = 9780, loss = 0.21810211, acc = 0.9
# [Validation] Batch ID = 9780, loss = 0.06802744, acc = 0.96
# [Train] Batch ID = 9790, loss = 0.039543275, acc = 0.98
# [Validation] Batch ID = 9790, loss = 0.07987173, acc = 0.98
# [Train] Batch ID = 9800, loss = 0.038118493, acc = 1.0
# [Validation] Batch ID = 9800, loss = 0.06455056, acc = 0.96
# [Train] Batch ID = 9810, loss = 0.23633945, acc = 0.76
# [Validation] Batch ID = 9810, loss = 0.091783926, acc = 0.92
# [Train] Batch ID = 9820, loss = 0.045362044, acc = 1.0
# [Validation] Batch ID = 9820, loss = 0.07508701, acc = 0.98
# [Train] Batch ID = 9830, loss = 0.26614228, acc = 0.72
# [Validation] Batch ID = 9830, loss = 0.07380684, acc = 0.98
# [Train] Batch ID = 9840, loss = 0.29129842, acc = 0.68
# [Validation] Batch ID = 9840, loss = 0.051828507, acc = 0.98
# [Train] Batch ID = 9850, loss = 0.24613352, acc = 0.74
# [Validation] Batch ID = 9850, loss = 0.04994248, acc = 0.98
# [Train] Batch ID = 9860, loss = 0.032489493, acc = 1.0
# [Validation] Batch ID = 9860, loss = 0.0770708, acc = 0.94
# [Train] Batch ID = 9870, loss = 0.017516064, acc = 1.0
# [Validation] Batch ID = 9870, loss = 0.07560039, acc = 0.98
# [Train] Batch ID = 9880, loss = 0.2815204, acc = 0.72
# [Validation] Batch ID = 9880, loss = 0.08731771, acc = 0.92
# [Train] Batch ID = 9890, loss = 0.03510301, acc = 1.0
# [Validation] Batch ID = 9890, loss = 0.09175884, acc = 0.92
# [Train] Batch ID = 9900, loss = 0.048328284, acc = 1.0
# [Validation] Batch ID = 9900, loss = 0.070205465, acc = 0.96
# [Train] Batch ID = 9910, loss = 0.02898528, acc = 1.0
# [Validation] Batch ID = 9910, loss = 0.101658404, acc = 0.9
# [Train] Batch ID = 9920, loss = 0.049029313, acc = 1.0
# [Validation] Batch ID = 9920, loss = 0.065435976, acc = 0.98
# [Train] Batch ID = 9930, loss = 0.04336498, acc = 0.98
# [Validation] Batch ID = 9930, loss = 0.06333865, acc = 0.96
# [Train] Batch ID = 9940, loss = 0.038421348, acc = 1.0
# [Validation] Batch ID = 9940, loss = 0.089486025, acc = 0.94
# [Train] Batch ID = 9950, loss = 0.04168241, acc = 1.0
# [Validation] Batch ID = 9950, loss = 0.06400741, acc = 0.98
# [Train] Batch ID = 9960, loss = 0.032115497, acc = 1.0
# [Validation] Batch ID = 9960, loss = 0.059208628, acc = 0.96
# [Train] Batch ID = 9970, loss = 0.031682715, acc = 1.0
# [Validation] Batch ID = 9970, loss = 0.06878746, acc = 0.96
# [Train] Batch ID = 9980, loss = 0.23138204, acc = 0.82
# [Validation] Batch ID = 9980, loss = 0.06114991, acc = 0.98
# [Train] Batch ID = 9990, loss = 0.036715213, acc = 1.0
# [Validation] Batch ID = 9990, loss = 0.07176357, acc = 0.98

# %%
# Test the model on the test set

# Evaluate all the dataset
loss, acc, predicted_class = model.evaluate_dataset(X_test, y_test)

print("Test Accuracy = ", acc)
print("Test Loss = ", loss)
# Out:
# Test Accuracy =  0.9481393507521774
# Test Loss =  0.078789815

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import os
images = []

# Read all image into the folder
for filename in os.listdir("from_web"):
    img = Image.open(os.path.join("from_web", filename))
    img = img.resize((32, 32))
    plt.imshow(img)
    plt.show()
    img = np.array(img) / 255
    images.append(img)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# Get the prediction
predictions = model.predict(images)

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# Plot the result
fig, axs = plt.subplots(5, 2, figsize=(10, 25))
axs = axs.ravel()
for i in range(10):
    if i%2 == 0:
        axs[i].axis('off')
        axs[i].imshow(images[i // 2])
        axs[i].set_title("Prediction: %s" % id_to_name[np.argmax(predictions[i // 2])])
    else:
        axs[i].bar(np.arange(43), predictions[i // 2])
        axs[i].set_ylabel("Softmax")
        axs[i].set_xlabel("Labels")

plt.show()

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
